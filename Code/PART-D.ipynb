# %% [markdown]
# In this part we are trying to view the Parquet file. Like how the datas are arranged inside it.
# Parquet files are very similar to excel file. But the differnece come in how they are stored and processed in the memory.

# %%
#libraries and Paths
import pandas as pd
import glob
import os

# %%
important_codes = ["IDRSSD", 
                   "RCFD2170","RCON2170","RCON2192", # assets
                   "RCON1400","RCFD1400","RCFD2122","RCON2122", #loans and leases
                   "RCFD1410","RCON1410","RCONF158","RCONF159","RCON1420","RCON1797","RCON5367","RCON5368","RCON1460","RCONF160","RCONF161" # real estate loans
                   "RCFD2165","RCON1600","RCFD1600",
                   "RCFD1763","RCON1763",#"RCFD1766","RCON1766", #commercial loans
                   "RCFDG301","RCFDG305","RCFDG309","RCFDG313","RCFDG317","RCFDG321","RCFDG301","RCFDK143","RCFDK147","RCFDK151","RCFDK155",
                   "RCON1043","RCON1044","RCON1209","RCON1280", #MBS in 2001
                   "RCON1709","RCON1713","RCON1733","RCON1736","RCONG389","RCONG390","RCONG393","RCONG394", #MBS IN 2011
                   "RCFD1975","RCON1975","RCONB538","RCONB539","RCONK137","RCONK207"# personal loans
                   "RCON3360",# quarterly avg of total loans]
                   "RCON6648","RCON2604","RCONJ474","RCONJ473", #time deposits
                   "RCON2210", #total Demand Deposits
                   "RCON2365", #total brokered deposits
                  ]

codes = [ c for c in important_codes ]
#print(codes)

# %%
# # Read parquet file
# file_path1 = r"C:\Users\32011\Dropbox\Call reports data\Output\All Quarters\2020-03-31\RC_2020-03-31.parquet"
# file_path2 = r"C:\Users\32011\Dropbox\Call reports data\Output\All Quarters\2020-03-31\RCA_2020-03-31.parquet"
# df1 = pd.read_parquet(file_path1)
# df1=df1.loc[:, df1.columns.str.strip() != '']
# # Show basic info about the file
# print("Shape of the data:", df1.shape)
# print("\nColumn names:\n", df1.columns.tolist())
# print("\nData types:\n", df1.dtypes)

# # Show first 10 rows
# print("\nSample data:\n", df1.head(10))


# df2 = pd.read_parquet(file_path2)
# df2=df2.loc[:, df2.columns.str.strip() != '']
# # df = df.loc[:, ~df.columns.str.contains("^Unnamed")] 
# print("data shape:", df2.shape)
# print("\n column names: \n", df2.columns.tolist())
# print("\n sample data: \n", df2.head(20))

# id_col1 = df1.columns[0]
# id_col2 = df2.columns[0]
# merged = pd.merge(df1, df2, left_on=id_col1, right_on =id_col2, how = "outer")
# print("shape of the merged data:", merged.shape)


# print(merged.head(10))

# %%
input_folder = r"C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder"
output_folder =r"C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Graphs\1"
os.makedirs(output_folder, exist_ok = True)
for quarter in os.listdir(input_folder):
    quarter_path = os.path.join(input_folder, quarter)
    if not os.path.isdir(quarter_path):
        continue
    print(f"Processing quarter: {quarter}")
    files = glob.glob(os.path.join(quarter_path, "*.parquet"))
    print("Found", len(files), "parquet files.")

    if not files:
        continue

    merged_df = None

    for i, file in enumerate(files, 1):
        #print(f"Reading {i}/{len(files)} -> {os.path.basename(file)}")
        
        # Read file
        df = pd.read_parquet(file)
        
        # Remove blank/unnamed columns
        df = df.loc[:, df.columns.str.strip() != ""]
        df = df.loc[:, ~df.columns.str.contains("^Unnamed")]
        
        # Identify ID column (first column)
        id_col = df.columns[0]
        df[id_col] = pd.to_numeric(df[id_col], errors = "coerce").astype("Int64")
        
        # Merge
        if merged_df is None:
            merged_df = df
        else:
            new_cols = [col for col in df.columns if col not in merged_df.columns or col == id_col]
            merged_df = pd.merge(merged_df, df[new_cols], on=id_col, how="outer")
    df_sorted = merged_df.sort_values(by = id_col, ascending= True)
    output_file = os.path.join(output_folder, f"merged_{quarter}.parquet")
    df_sorted.to_parquet(output_file, index= False)
    print("\nFinal merged shape:", df_sorted.shape)
# print("\nColumns:\n", df_sorted.columns.tolist())
# print("\nSample data:\n", df_sorted.head(10))


    print(f"Merged file saved to:{output_file}")
# Out:
# Processing quarter: 2008-03-31
# Found 30 parquet files.
#
# Final merged shape: (7740, 2198)
# Merged file saved to:C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Graphs\1\merged_2008-03-31.parquet
# Processing quarter: 2008-06-30
# Found 30 parquet files.
#
# Final merged shape: (7698, 2198)
# Merged file saved to:C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Graphs\1\merged_2008-06-30.parquet
# Processing quarter: 2008-09-30
# Found 30 parquet files.
#
# Final merged shape: (7640, 2198)
# Merged file saved to:C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Graphs\1\merged_2008-09-30.parquet
# Processing quarter: 2008-12-31
# Found 30 parquet files.
#
# Final merged shape: (7568, 2200)
# Merged file saved to:C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Graphs\1\merged_2008-12-31.parquet
# Processing quarter: 2009-03-31
# Found 30 parquet files.
#
# Final merged shape: (7520, 2230)
# Merged file saved to:C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Graphs\1\merged_2009-03-31.parquet
# Processing quarter: 2009-06-30
# Found 33 parquet files.
#
# Final merged shape: (7476, 2714)
# Merged file saved to:C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Graphs\1\merged_2009-06-30.parquet
# Processing quarter: 2009-09-30
# Found 33 parquet files.
#
# Final merged shape: (7394, 2714)
# Merged file saved to:C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Graphs\1\merged_2009-09-30.parquet
# Processing quarter: 2009-12-31
# Found 34 parquet files.
#
# Final merged shape: (7322, 2822)
# Merged file saved to:C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Graphs\1\merged_2009-12-31.parquet
# Processing quarter: 2010-03-31
# Found 34 parquet files.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 36
#      34     else:
#      35         new_cols = [col for col in df.columns if col not in merged_df.columns or col == id_col]
# ---> 36         merged_df = pd.merge(merged_df, df[new_cols], on=id_col, how="outer")
#      37 df_sorted = merged_df.sort_values(by = id_col, ascending= True)
#      38 output_file = os.path.join(output_folder, f"merged_{quarter}.parquet")
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\core\reshape\merge.py:184, in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     169 else:
#     170     op = _MergeOperation(
#     171         left_df,
#     172         right_df,
#    (...)
#     182         validate=validate,
#     183     )
# --> 184     return op.get_result(copy=copy)
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\core\reshape\merge.py:888, in _MergeOperation.get_result(self, copy)
#     884     self.left, self.right = self._indicator_pre_merge(self.left, self.right)
#     886 join_index, left_indexer, right_indexer = self._get_join_info()
# --> 888 result = self._reindex_and_concat(
#     889     join_index, left_indexer, right_indexer, copy=copy
#     890 )
#     891 result = result.__finalize__(self, method=self._merge_type)
#     893 if self.indicator:
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\core\reshape\merge.py:879, in _MergeOperation._reindex_and_concat(self, join_index, left_indexer, right_indexer, copy)
#     877 left.columns = llabels
#     878 right.columns = rlabels
# --> 879 result = concat([left, right], axis=1, copy=copy)
#     880 return result
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\core\reshape\concat.py:395, in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     380     copy = False
#     382 op = _Concatenator(
#     383     objs,
#     384     axis=axis,
#    (...)
#     392     sort=sort,
#     393 )
# --> 395 return op.get_result()
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\core\reshape\concat.py:684, in _Concatenator.get_result(self)
#     680             indexers[ax] = obj_labels.get_indexer(new_labels)
#     682     mgrs_indexers.append((obj._mgr, indexers))
# --> 684 new_data = concatenate_managers(
#     685     mgrs_indexers, self.new_axes, concat_axis=self.bm_axis, copy=self.copy
#     686 )
#     687 if not self.copy and not using_copy_on_write():
#     688     new_data._consolidate_inplace()
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\core\internals\concat.py:131, in concatenate_managers(mgrs_indexers, axes, concat_axis, copy)
#     124 # Assertions disabled for performance
#     125 # for tup in mgrs_indexers:
#     126 #    # caller is responsible for ensuring this
#     127 #    indexers = tup[1]
#     128 #    assert concat_axis not in indexers
#     130 if concat_axis == 0:
# --> 131     mgrs = _maybe_reindex_columns_na_proxy(axes, mgrs_indexers, needs_copy)
#     132     return mgrs[0].concat_horizontal(mgrs, axes)
#     134 if len(mgrs_indexers) > 0 and mgrs_indexers[0][0].nblocks > 0:
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\core\internals\concat.py:230, in _maybe_reindex_columns_na_proxy(axes, mgrs_indexers, needs_copy)
#     220         mgr = mgr.reindex_indexer(
#     221             axes[i],
#     222             indexers[i],
#    (...)
#     227             use_na_proxy=True,  # only relevant for i==0
#     228         )
#     229     if needs_copy and not indexers:
# --> 230         mgr = mgr.copy()
#     232     new_mgrs.append(mgr)
#     233 return new_mgrs
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\core\internals\managers.py:604, in BaseBlockManager.copy(self, deep)
#     601         res._blklocs = self._blklocs.copy()
#     603 if deep:
# --> 604     res._consolidate_inplace()
#     605 return res
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\core\internals\managers.py:1791, in BlockManager._consolidate_inplace(self)
#    1789 self._is_consolidated = True
#    1790 self._known_consolidated = True
# -> 1791 self._rebuild_blknos_and_blklocs()
#
# File internals.pyx:755, in pandas._libs.internals.BlockManager._rebuild_blknos_and_blklocs()
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\core\internals\base.py:84, in DataManager.shape(self)
#      82 @property
#      83 def shape(self) -> Shape:
# ---> 84     return tuple(len(ax) for ax in self.axes)
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\core\internals\base.py:84, in <genexpr>(.0)
#      82 @property
#      83 def shape(self) -> Shape:
# ---> 84     return tuple(len(ax) for ax in self.axes)
#
# KeyboardInterrupt:

# %%
merged_file = r"C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\merged_parquet_all.parquet"
df = pd.read_parquet(merged_file)
# Ensure we have the IDRSSD column
id_col = df.columns[0]

# Check available codes
available_codes = [c for c in codes if c in df.columns]
missing_codes = [c for c in codes if c not in df.columns]

# Inform about missing codes
if missing_codes:
    print("⚠️ These codes were not found in the data:", missing_codes)

# Keep only IDRSSD + found codes
filtered_df = df[[id_col] + available_codes]

# Save to parquet
output_file = "filtered_codes.parquet"
filtered_df.to_parquet(output_file, index=False)

print(f"\n✅ Filtered parquet file saved as {output_file}")
print("Shape:", filtered_df.shape)
print("Columns:", filtered_df.columns.tolist())
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[126], line 2
#       1 merged_file = r"C:\Users\32011\Dropbox\Call reports data\Output\Merged Quarters\merged_parquet_all.parquet"
# ----> 2 df = pd.read_parquet(merged_file)
#       3 # Ensure we have the IDRSSD column
#       4 id_col = df.columns[0]
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\io\parquet.py:667, in read_parquet(path, engine, columns, storage_options, use_nullable_dtypes, dtype_backend, filesystem, filters, **kwargs)
#     664     use_nullable_dtypes = False
#     665 check_dtype_backend(dtype_backend)
# --> 667 return impl.read(
#     668     path,
#     669     columns=columns,
#     670     filters=filters,
#     671     storage_options=storage_options,
#     672     use_nullable_dtypes=use_nullable_dtypes,
#     673     dtype_backend=dtype_backend,
#     674     filesystem=filesystem,
#     675     **kwargs,
#     676 )
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\io\parquet.py:267, in PyArrowImpl.read(self, path, columns, filters, use_nullable_dtypes, dtype_backend, storage_options, filesystem, **kwargs)
#     264 if manager == "array":
#     265     to_pandas_kwargs["split_blocks"] = True  # type: ignore[assignment]
# --> 267 path_or_handle, handles, filesystem = _get_path_or_handle(
#     268     path,
#     269     filesystem,
#     270     storage_options=storage_options,
#     271     mode="rb",
#     272 )
#     273 try:
#     274     pa_table = self.api.parquet.read_table(
#     275         path_or_handle,
#     276         columns=columns,
#    (...)
#     279         **kwargs,
#     280     )
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\io\parquet.py:140, in _get_path_or_handle(path, fs, storage_options, mode, is_dir)
#     130 handles = None
#     131 if (
#     132     not fs
#     133     and not is_dir
#    (...)
#     138     # fsspec resources can also point to directories
#     139     # this branch is used for example when reading from non-fsspec URLs
# --> 140     handles = get_handle(
#     141         path_or_handle, mode, is_text=False, storage_options=storage_options
#     142     )
#     143     fs = None
#     144     path_or_handle = handles.handle
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\io\common.py:882, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#    (...)
#     878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
# --> 882         handle = open(handle, ioargs.mode)
#     883     handles.append(handle)
#     885 # Convert BytesIO or file objects passed with an encoding
#
# FileNotFoundError: [Errno 2] No such file or directory: 'C:\\Users\\32011\\Dropbox\\Call reports data\\Output\\Merged Quarters\\merged_parquet_all.parquet'

# %%
# df = pd.read_parquet(merged_file)
# code = "RCON2216_y"

# if code in df.columns:
#     print(df[[df.columns[0], code]])
# else:
#     print(f"⚠️ Code '{code}' not found in merged file!")

# %% [markdown]
# Creating a smaller parquet file from the bigger parquet file using the important pre specified codes. Please note that not all the codes in the important codes dictionary will find their place in the final one, many codes are not there in the merged file

# %%
parq_folder1 = r"C:\Users\32011\Dropbox\Rajib\Call reports data\Output\rawdata\Parq. folder\1"
parq_folder2 = r"C:\Users\32011\Dropbox\Rajib\Call reports data\Output\rawdata\Parq. folder\2"
os.makedirs(parq_folder2, exist_ok = True)

for file in os.listdir(parq_folder1):
    if not file.endswith(".parquet"):
        continue
    merged_file = os.path.join(parq_folder1, file)
    print(f"processing: {file}")
    df = pd.read_parquet(merged_file)


    # Keep only the columns that exist in the file
    cols_to_keep = [col for col in codes if col in df.columns]
    if not cols_to_keep:
        print("No matching codes found, skipping. ")
        continue
        
    subset_df = df[cols_to_keep]

    # Save to new parquet
    output_file = os.path.join(parq_folder2, f"{file}")
    subset_df.to_parquet(output_file, index=False)


    print("Subset parquet saved to:", {output_file})
    print(f"Shape: {subset_df.shape}")
    print("Columns:", subset_df.columns.tolist())
# Out:
# processing: 2001-03-31.parquet
# Subset parquet saved to: {'C:\\Users\\32011\\Dropbox\\Rajib\\Call reports data\\Output\\rawdata\\Parq. folder\\2\\2001-03-31.parquet'}
# Shape: (8857, 9)
# Columns: ['IDRSSD', 'RCON1043', 'RCON1044', 'RCON1209', 'RCON1280', 'RCON1709', 'RCON1713', 'RCON1733', 'RCON1736']
# processing: 2001-06-30.parquet
# Subset parquet saved to: {'C:\\Users\\32011\\Dropbox\\Rajib\\Call reports data\\Output\\rawdata\\Parq. folder\\2\\2001-06-30.parquet'}
# Shape: (8790, 9)
# Columns: ['IDRSSD', 'RCON1043', 'RCON1044', 'RCON1209', 'RCON1280', 'RCON1709', 'RCON1713', 'RCON1733', 'RCON1736']
# processing: 2001-09-30.parquet
# Subset parquet saved to: {'C:\\Users\\32011\\Dropbox\\Rajib\\Call reports data\\Output\\rawdata\\Parq. folder\\2\\2001-09-30.parquet'}
# Shape: (8758, 9)
# Columns: ['IDRSSD', 'RCON1043', 'RCON1044', 'RCON1209', 'RCON1280', 'RCON1709', 'RCON1713', 'RCON1733', 'RCON1736']
# processing: 2001-12-31.parquet
# Subset parquet saved to: {'C:\\Users\\32011\\Dropbox\\Rajib\\Call reports data\\Output\\rawdata\\Parq. folder\\2\\2001-12-31.parquet'}
# Shape: (8689, 9)
# Columns: ['IDRSSD', 'RCON1043', 'RCON1044', 'RCON1209', 'RCON1280', 'RCON1709', 'RCON1713', 'RCON1733', 'RCON1736']
# processing: 2002-03-31.parquet
# Subset parquet saved to: {'C:\\Users\\32011\\Dropbox\\Rajib\\Call reports data\\Output\\rawdata\\Parq. folder\\2\\2002-03-31.parquet'}
# Shape: (8605, 9)
# Columns: ['IDRSSD', 'RCON1043', 'RCON1044', 'RCON1209', 'RCON1280', 'RCON1709', 'RCON1713', 'RCON1733', 'RCON1736']
# processing: 2002-06-30.parquet
# Subset parquet saved to: {'C:\\Users\\32011\\Dropbox\\Rajib\\Call reports data\\Output\\rawdata\\Parq. folder\\2\\2002-06-30.parquet'}
# Shape: (8562, 9)
# Columns: ['IDRSSD', 'RCON1043', 'RCON1044', 'RCON1209', 'RCON1280', 'RCON1709', 'RCON1713', 'RCON1733', 'RCON1736']
# processing: 2002-09-30.parquet
# Subset parquet saved to: {'C:\\Users\\32011\\Dropbox\\Rajib\\Call reports data\\Output\\rawdata\\Parq. folder\\2\\2002-09-30.parquet'}
# Shape: (8522, 9)
# Columns: ['IDRSSD', 'RCON1043', 'RCON1044', 'RCON1209', 'RCON1280', 'RCON1709', 'RCON1713', 'RCON1733', 'RCON1736']
# processing: 2002-12-31.parquet
# Subset parquet saved to: {'C:\\Users\\32011\\Dropbox\\Rajib\\Call reports data\\Output\\rawdata\\Parq. folder\\2\\2002-12-31.parquet'}
# Shape: (8468, 9)
# Columns: ['IDRSSD', 'RCON1043', 'RCON1044', 'RCON1209', 'RCON1280', 'RCON1709', 'RCON1713', 'RCON1733', 'RCON1736']
# processing: 2003-03-31.parquet
# Subset parquet saved to: {'C:\\Users\\32011\\Dropbox\\Rajib\\Call reports data\\Output\\rawdata\\Parq. folder\\2\\2003-03-31.parquet'}
# Shape: (8445, 9)
# Columns: ['IDRSSD', 'RCON1043', 'RCON1044', 'RCON1209', 'RCON1280', 'RCON1709', 'RCON1713', 'RCON1733', 'RCON1736']
# processing: 2003-06-30.parquet
# Subset parquet saved to: {'C:\\Users\\32011\\Dropbox\\Rajib\\Call reports data\\Output\\rawdata\\Parq. folder\\2\\2003-06-30.parquet'}
# Shape: (8410, 9)
# Columns: ['IDRSSD', 'RCON1043', 'RCON1044', 'RCON1209', 'RCON1280', 'RCON1709', 'RCON1713', 'RCON1733', 'RCON1736']
# processing: 2003-09-30.parquet
# Subset parquet saved to: {'C:\\Users\\32011\\Dropbox\\Rajib\\Call reports data\\Output\\rawdata\\Parq. folder\\2\\2003-09-30.parquet'}
# Shape: (8391, 9)
# Columns: ['IDRSSD', 'RCON1043', 'RCON1044', 'RCON1209', 'RCON1280', 'RCON1709', 'RCON1713', 'RCON1733', 'RCON1736']
# processing: 2003-12-31.parquet
# Subset parquet saved to: {'C:\\Users\\32011\\Dropbox\\Rajib\\Call reports data\\Output\\rawdata\\Parq. folder\\2\\2003-12-31.parquet'}
# Shape: (8348, 9)
# Columns: ['IDRSSD', 'RCON1043', 'RCON1044', 'RCON1209', 'RCON1280', 'RCON1709', 'RCON1713', 'RCON1733', 'RCON1736']
# processing: 2004-03-31.parquet
# Subset parquet saved to: {'C:\\Users\\32011\\Dropbox\\Rajib\\Call reports data\\Output\\rawdata\\Parq. folder\\2\\2004-03-31.parquet'}
# Shape: (8286, 9)
# Columns: ['IDRSSD', 'RCON1043', 'RCON1044', 'RCON1209', 'RCON1280', 'RCON1709', 'RCON1713', 'RCON1733', 'RCON1736']
# processing: 2004-06-30.parquet
# Subset parquet saved to: {'C:\\Users\\32011\\Dropbox\\Rajib\\Call reports data\\Output\\rawdata\\Parq. folder\\2\\2004-06-30.parquet'}
# Shape: (8261, 9)
# Columns: ['IDRSSD', 'RCON1043', 'RCON1044', 'RCON1209', 'RCON1280', 'RCON1709', 'RCON1713', 'RCON1733', 'RCON1736']
# processing: 2004-09-30.parquet
# Subset parquet saved to: {'C:\\Users\\32011\\Dropbox\\Rajib\\Call reports data\\Output\\rawdata\\Parq. folder\\2\\2004-09-30.parquet'}
# Shape: (8219, 9)
# Columns: ['IDRSSD', 'RCON1043', 'RCON1044', 'RCON1209', 'RCON1280', 'RCON1709', 'RCON1713', 'RCON1733', 'RCON1736']
# processing: 2004-12-31.parquet
# Subset parquet saved to: {'C:\\Users\\32011\\Dropbox\\Rajib\\Call reports data\\Output\\rawdata\\Parq. folder\\2\\2004-12-31.parquet'}
# Shape: (8179, 9)
# Columns: ['IDRSSD', 'RCON1043', 'RCON1044', 'RCON1209', 'RCON1280', 'RCON1709', 'RCON1713', 'RCON1733', 'RCON1736']
# processing: 2005-03-31.parquet
# Subset parquet saved to: {'C:\\Users\\32011\\Dropbox\\Rajib\\Call reports data\\Output\\rawdata\\Parq. folder\\2\\2005-03-31.parquet'}
# Shape: (8141, 9)
# Columns: ['IDRSSD', 'RCON1043', 'RCON1044', 'RCON1209', 'RCON1280', 'RCON1709', 'RCON1713', 'RCON1733', 'RCON1736']
# processing: 2005-06-30.parquet
# Subset parquet saved to: {'C:\\Users\\32011\\Dropbox\\Rajib\\Call reports data\\Output\\rawdata\\Parq. folder\\2\\2005-06-30.parquet'}
# Shape: (8084, 9)
# Columns: ['IDRSSD', 'RCON1043', 'RCON1044', 'RCON1209', 'RCON1280', 'RCON1709', 'RCON1713', 'RCON1733', 'RCON1736']
# processing: 2005-09-30.parquet
# Subset parquet saved to: {'C:\\Users\\32011\\Dropbox\\Rajib\\Call reports data\\Output\\rawdata\\Parq. folder\\2\\2005-09-30.parquet'}
# Shape: (8079, 9)
# Columns: ['IDRSSD', 'RCON1043', 'RCON1044', 'RCON1209', 'RCON1280', 'RCON1709', 'RCON1713', 'RCON1733', 'RCON1736']
# processing: 2005-12-31.parquet
# Subset parquet saved to: {'C:\\Users\\32011\\Dropbox\\Rajib\\Call reports data\\Output\\rawdata\\Parq. folder\\2\\2005-12-31.parquet'}
# Shape: (8056, 9)
# Columns: ['IDRSSD', 'RCON1043', 'RCON1044', 'RCON1209', 'RCON1280', 'RCON1709', 'RCON1713', 'RCON1733', 'RCON1736']
# processing: 2006-03-31.parquet
# Subset parquet saved to: {'C:\\Users\\32011\\Dropbox\\Rajib\\Call reports data\\Output\\rawdata\\Parq. folder\\2\\2006-03-31.parquet'}
# Shape: (8020, 9)
# Columns: ['IDRSSD', 'RCON1043', 'RCON1044', 'RCON1209', 'RCON1280', 'RCON1709', 'RCON1713', 'RCON1733', 'RCON1736']
# processing: 2006-06-30.parquet
# Subset parquet saved to: {'C:\\Users\\32011\\Dropbox\\Rajib\\Call reports data\\Output\\rawdata\\Parq. folder\\2\\2006-06-30.parquet'}
# Shape: (8010, 9)
# Columns: ['IDRSSD', 'RCON1043', 'RCON1044', 'RCON1209', 'RCON1280', 'RCON1709', 'RCON1713', 'RCON1733', 'RCON1736']
# processing: 2006-09-30.parquet
# Subset parquet saved to: {'C:\\Users\\32011\\Dropbox\\Rajib\\Call reports data\\Output\\rawdata\\Parq. folder\\2\\2006-09-30.parquet'}
# Shape: (7978, 9)
# Columns: ['IDRSSD', 'RCON1043', 'RCON1044', 'RCON1209', 'RCON1280', 'RCON1709', 'RCON1713', 'RCON1733', 'RCON1736']
# processing: 2006-12-31.parquet
# Subset parquet saved to: {'C:\\Users\\32011\\Dropbox\\Rajib\\Call reports data\\Output\\rawdata\\Parq. folder\\2\\2006-12-31.parquet'}
# Shape: (7922, 9)
# Columns: ['IDRSSD', 'RCON1043', 'RCON1044', 'RCON1209', 'RCON1280', 'RCON1709', 'RCON1713', 'RCON1733', 'RCON1736']
# processing: 2007-03-31.parquet
# Subset parquet saved to: {'C:\\Users\\32011\\Dropbox\\Rajib\\Call reports data\\Output\\rawdata\\Parq. folder\\2\\2007-03-31.parquet'}
# Shape: (7896, 9)
# Columns: ['IDRSSD', 'RCON1043', 'RCON1044', 'RCON1209', 'RCON1280', 'RCON1709', 'RCON1713', 'RCON1733', 'RCON1736']
# processing: 2007-06-30.parquet
# Subset parquet saved to: {'C:\\Users\\32011\\Dropbox\\Rajib\\Call reports data\\Output\\rawdata\\Parq. folder\\2\\2007-06-30.parquet'}
# Shape: (7862, 9)
# Columns: ['IDRSSD', 'RCON1043', 'RCON1044', 'RCON1209', 'RCON1280', 'RCON1709', 'RCON1713', 'RCON1733', 'RCON1736']
# processing: 2007-09-30.parquet
# Subset parquet saved to: {'C:\\Users\\32011\\Dropbox\\Rajib\\Call reports data\\Output\\rawdata\\Parq. folder\\2\\2007-09-30.parquet'}
# Shape: (7811, 9)
# Columns: ['IDRSSD', 'RCON1043', 'RCON1044', 'RCON1209', 'RCON1280', 'RCON1709', 'RCON1713', 'RCON1733', 'RCON1736']
# processing: 2007-12-31.parquet
# Subset parquet saved to: {'C:\\Users\\32011\\Dropbox\\Rajib\\Call reports data\\Output\\rawdata\\Parq. folder\\2\\2007-12-31.parquet'}
# Shape: (7788, 9)
# Columns: ['IDRSSD', 'RCON1043', 'RCON1044', 'RCON1209', 'RCON1280', 'RCON1709', 'RCON1713', 'RCON1733', 'RCON1736']
# processing: 2008-03-31.parquet
# Subset parquet saved to: {'C:\\Users\\32011\\Dropbox\\Rajib\\Call reports data\\Output\\rawdata\\Parq. folder\\2\\2008-03-31.parquet'}
# Shape: (7740, 9)
# Columns: ['IDRSSD', 'RCON1043', 'RCON1044', 'RCON1209', 'RCON1280', 'RCON1709', 'RCON1713', 'RCON1733', 'RCON1736']
# processing: 2008-06-30.parquet
# Subset parquet saved to: {'C:\\Users\\32011\\Dropbox\\Rajib\\Call reports data\\Output\\rawdata\\Parq. folder\\2\\2008-06-30.parquet'}
# Shape: (7698, 9)
# Columns: ['IDRSSD', 'RCON1043', 'RCON1044', 'RCON1209', 'RCON1280', 'RCON1709', 'RCON1713', 'RCON1733', 'RCON1736']
# processing: 2008-09-30.parquet
# Subset parquet saved to: {'C:\\Users\\32011\\Dropbox\\Rajib\\Call reports data\\Output\\rawdata\\Parq. folder\\2\\2008-09-30.parquet'}
# Shape: (7640, 9)
# Columns: ['IDRSSD', 'RCON1043', 'RCON1044', 'RCON1209', 'RCON1280', 'RCON1709', 'RCON1713', 'RCON1733', 'RCON1736']
# processing: 2008-12-31.parquet
# Subset parquet saved to: {'C:\\Users\\32011\\Dropbox\\Rajib\\Call reports data\\Output\\rawdata\\Parq. folder\\2\\2008-12-31.parquet'}
# Shape: (7568, 9)
# Columns: ['IDRSSD', 'RCON1043', 'RCON1044', 'RCON1209', 'RCON1280', 'RCON1709', 'RCON1713', 'RCON1733', 'RCON1736']
# processing: 2009-03-31.parquet
# Subset parquet saved to: {'C:\\Users\\32011\\Dropbox\\Rajib\\Call reports data\\Output\\rawdata\\Parq. folder\\2\\2009-03-31.parquet'}
# Shape: (7520, 9)
# Columns: ['IDRSSD', 'RCON1043', 'RCON1044', 'RCON1209', 'RCON1280', 'RCON1709', 'RCON1713', 'RCON1733', 'RCON1736']
# processing: 2009-06-30.parquet
# Subset parquet saved to: {'C:\\Users\\32011\\Dropbox\\Rajib\\Call reports data\\Output\\rawdata\\Parq. folder\\2\\2009-06-30.parquet'}
# Shape: (7476, 9)
# Columns: ['IDRSSD', 'RCON1709', 'RCON1713', 'RCON1733', 'RCON1736', 'RCONG389', 'RCONG390', 'RCONG393', 'RCONG394']
# processing: 2009-09-30.parquet
# Subset parquet saved to: {'C:\\Users\\32011\\Dropbox\\Rajib\\Call reports data\\Output\\rawdata\\Parq. folder\\2\\2009-09-30.parquet'}
# Shape: (7394, 9)
# Columns: ['IDRSSD', 'RCON1709', 'RCON1713', 'RCON1733', 'RCON1736', 'RCONG389', 'RCONG390', 'RCONG393', 'RCONG394']
# processing: 2009-12-31.parquet
# Subset parquet saved to: {'C:\\Users\\32011\\Dropbox\\Rajib\\Call reports data\\Output\\rawdata\\Parq. folder\\2\\2009-12-31.parquet'}
# Shape: (7322, 9)
# Columns: ['IDRSSD', 'RCON1709', 'RCON1713', 'RCON1733', 'RCON1736', 'RCONG389', 'RCONG390', 'RCONG393', 'RCONG394']
# processing: 2010-03-31.parquet
# Subset parquet saved to: {'C:\\Users\\32011\\Dropbox\\Rajib\\Call reports data\\Output\\rawdata\\Parq. folder\\2\\2010-03-31.parquet'}
# Shape: (7250, 9)
# Columns: ['IDRSSD', 'RCON1709', 'RCON1713', 'RCON1733', 'RCON1736', 'RCONG389', 'RCONG390', 'RCONG393', 'RCONG394']
# processing: 2010-06-30.parquet
# Subset parquet saved to: {'C:\\Users\\32011\\Dropbox\\Rajib\\Call reports data\\Output\\rawdata\\Parq. folder\\2\\2010-06-30.parquet'}
# Shape: (7155, 9)
# Columns: ['IDRSSD', 'RCON1709', 'RCON1713', 'RCON1733', 'RCON1736', 'RCONG389', 'RCONG390', 'RCONG393', 'RCONG394']
# processing: 2010-09-30.parquet
# Subset parquet saved to: {'C:\\Users\\32011\\Dropbox\\Rajib\\Call reports data\\Output\\rawdata\\Parq. folder\\2\\2010-09-30.parquet'}
# Shape: (7096, 9)
# Columns: ['IDRSSD', 'RCON1709', 'RCON1713', 'RCON1733', 'RCON1736', 'RCONG389', 'RCONG390', 'RCONG393', 'RCONG394']
# processing: 2010-12-31.parquet
# Subset parquet saved to: {'C:\\Users\\32011\\Dropbox\\Rajib\\Call reports data\\Output\\rawdata\\Parq. folder\\2\\2010-12-31.parquet'}
# Shape: (7002, 9)
# Columns: ['IDRSSD', 'RCON1709', 'RCON1713', 'RCON1733', 'RCON1736', 'RCONG389', 'RCONG390', 'RCONG393', 'RCONG394']
# processing: 2011-03-31.parquet
# Subset parquet saved to: {'C:\\Users\\32011\\Dropbox\\Rajib\\Call reports data\\Output\\rawdata\\Parq. folder\\2\\2011-03-31.parquet'}
# Shape: (6925, 9)
# Columns: ['IDRSSD', 'RCON1709', 'RCON1713', 'RCON1733', 'RCON1736', 'RCONG389', 'RCONG390', 'RCONG393', 'RCONG394']
# processing: 2011-06-30.parquet
# Subset parquet saved to: {'C:\\Users\\32011\\Dropbox\\Rajib\\Call reports data\\Output\\rawdata\\Parq. folder\\2\\2011-06-30.parquet'}
# Shape: (6880, 9)
# Columns: ['IDRSSD', 'RCON1709', 'RCON1713', 'RCON1733', 'RCON1736', 'RCONG389', 'RCONG390', 'RCONG393', 'RCONG394']
# processing: 2011-09-30.parquet
# Subset parquet saved to: {'C:\\Users\\32011\\Dropbox\\Rajib\\Call reports data\\Output\\rawdata\\Parq. folder\\2\\2011-09-30.parquet'}
# Shape: (6823, 9)
# Columns: ['IDRSSD', 'RCON1709', 'RCON1713', 'RCON1733', 'RCON1736', 'RCONG389', 'RCONG390', 'RCONG393', 'RCONG394']
# processing: 2011-12-31.parquet
# Subset parquet saved to: {'C:\\Users\\32011\\Dropbox\\Rajib\\Call reports data\\Output\\rawdata\\Parq. folder\\2\\2011-12-31.parquet'}
# Shape: (6792, 9)
# Columns: ['IDRSSD', 'RCON1709', 'RCON1713', 'RCON1733', 'RCON1736', 'RCONG389', 'RCONG390', 'RCONG393', 'RCONG394']
# processing: 2012-03-31.parquet
# Subset parquet saved to: {'C:\\Users\\32011\\Dropbox\\Rajib\\Call reports data\\Output\\rawdata\\Parq. folder\\2\\2012-03-31.parquet'}
# Shape: (7378, 9)
# Columns: ['IDRSSD', 'RCON1709', 'RCON1713', 'RCON1733', 'RCON1736', 'RCONG389', 'RCONG390', 'RCONG393', 'RCONG394']
# processing: 2012-06-30.parquet
# Subset parquet saved to: {'C:\\Users\\32011\\Dropbox\\Rajib\\Call reports data\\Output\\rawdata\\Parq. folder\\2\\2012-06-30.parquet'}
# Shape: (7316, 9)
# Columns: ['IDRSSD', 'RCON1709', 'RCON1713', 'RCON1733', 'RCON1736', 'RCONG389', 'RCONG390', 'RCONG393', 'RCONG394']
# processing: 2012-09-30.parquet
# Subset parquet saved to: {'C:\\Users\\32011\\Dropbox\\Rajib\\Call reports data\\Output\\rawdata\\Parq. folder\\2\\2012-09-30.parquet'}
# Shape: (7252, 9)
# Columns: ['IDRSSD', 'RCON1709', 'RCON1713', 'RCON1733', 'RCON1736', 'RCONG389', 'RCONG390', 'RCONG393', 'RCONG394']
# processing: 2012-12-31.parquet
# Subset parquet saved to: {'C:\\Users\\32011\\Dropbox\\Rajib\\Call reports data\\Output\\rawdata\\Parq. folder\\2\\2012-12-31.parquet'}
# Shape: (7155, 9)
# Columns: ['IDRSSD', 'RCON1709', 'RCON1713', 'RCON1733', 'RCON1736', 'RCONG389', 'RCONG390', 'RCONG393', 'RCONG394']
# processing: 2013-03-31.parquet
# Subset parquet saved to: {'C:\\Users\\32011\\Dropbox\\Rajib\\Call reports data\\Output\\rawdata\\Parq. folder\\2\\2013-03-31.parquet'}
# Shape: (7091, 9)
# Columns: ['IDRSSD', 'RCON1709', 'RCON1713', 'RCON1733', 'RCON1736', 'RCONG389', 'RCONG390', 'RCONG393', 'RCONG394']
# processing: 2013-06-30.parquet
# Subset parquet saved to: {'C:\\Users\\32011\\Dropbox\\Rajib\\Call reports data\\Output\\rawdata\\Parq. folder\\2\\2013-06-30.parquet'}
# Shape: (7011, 9)
# Columns: ['IDRSSD', 'RCON1709', 'RCON1713', 'RCON1733', 'RCON1736', 'RCONG389', 'RCONG390', 'RCONG393', 'RCONG394']
# processing: 2013-09-30.parquet
# Subset parquet saved to: {'C:\\Users\\32011\\Dropbox\\Rajib\\Call reports data\\Output\\rawdata\\Parq. folder\\2\\2013-09-30.parquet'}
# Shape: (6962, 9)
# Columns: ['IDRSSD', 'RCON1709', 'RCON1713', 'RCON1733', 'RCON1736', 'RCONG389', 'RCONG390', 'RCONG393', 'RCONG394']
# processing: 2013-12-31.parquet
# Subset parquet saved to: {'C:\\Users\\32011\\Dropbox\\Rajib\\Call reports data\\Output\\rawdata\\Parq. folder\\2\\2013-12-31.parquet'}
# Shape: (6888, 9)
# Columns: ['IDRSSD', 'RCON1709', 'RCON1713', 'RCON1733', 'RCON1736', 'RCONG389', 'RCONG390', 'RCONG393', 'RCONG394']
# processing: 2014-03-31.parquet
# Subset parquet saved to: {'C:\\Users\\32011\\Dropbox\\Rajib\\Call reports data\\Output\\rawdata\\Parq. folder\\2\\2014-03-31.parquet'}
# Shape: (6807, 9)
# Columns: ['IDRSSD', 'RCON1709', 'RCON1713', 'RCON1733', 'RCON1736', 'RCONG389', 'RCONG390', 'RCONG393', 'RCONG394']
# processing: 2014-06-30.parquet
# Subset parquet saved to: {'C:\\Users\\32011\\Dropbox\\Rajib\\Call reports data\\Output\\rawdata\\Parq. folder\\2\\2014-06-30.parquet'}
# Shape: (6730, 9)
# Columns: ['IDRSSD', 'RCON1709', 'RCON1713', 'RCON1733', 'RCON1736', 'RCONG389', 'RCONG390', 'RCONG393', 'RCONG394']
# processing: 2014-09-30.parquet
# Subset parquet saved to: {'C:\\Users\\32011\\Dropbox\\Rajib\\Call reports data\\Output\\rawdata\\Parq. folder\\2\\2014-09-30.parquet'}
# Shape: (6665, 9)
# Columns: ['IDRSSD', 'RCON1709', 'RCON1713', 'RCON1733', 'RCON1736', 'RCONG389', 'RCONG390', 'RCONG393', 'RCONG394']
# processing: 2014-12-31.parquet
# Subset parquet saved to: {'C:\\Users\\32011\\Dropbox\\Rajib\\Call reports data\\Output\\rawdata\\Parq. folder\\2\\2014-12-31.parquet'}
# Shape: (6576, 9)
# Columns: ['IDRSSD', 'RCON1709', 'RCON1713', 'RCON1733', 'RCON1736', 'RCONG389', 'RCONG390', 'RCONG393', 'RCONG394']
# processing: 2015-03-31.parquet
# Subset parquet saved to: {'C:\\Users\\32011\\Dropbox\\Rajib\\Call reports data\\Output\\rawdata\\Parq. folder\\2\\2015-03-31.parquet'}
# Shape: (6487, 9)
# Columns: ['IDRSSD', 'RCON1709', 'RCON1713', 'RCON1733', 'RCON1736', 'RCONG389', 'RCONG390', 'RCONG393', 'RCONG394']
# processing: 2015-06-30.parquet
# Subset parquet saved to: {'C:\\Users\\32011\\Dropbox\\Rajib\\Call reports data\\Output\\rawdata\\Parq. folder\\2\\2015-06-30.parquet'}
# Shape: (6420, 9)
# Columns: ['IDRSSD', 'RCON1709', 'RCON1713', 'RCON1733', 'RCON1736', 'RCONG389', 'RCONG390', 'RCONG393', 'RCONG394']
# processing: 2015-09-30.parquet
# Subset parquet saved to: {'C:\\Users\\32011\\Dropbox\\Rajib\\Call reports data\\Output\\rawdata\\Parq. folder\\2\\2015-09-30.parquet'}
# Shape: (6344, 9)
# Columns: ['IDRSSD', 'RCON1709', 'RCON1713', 'RCON1733', 'RCON1736', 'RCONG389', 'RCONG390', 'RCONG393', 'RCONG394']
# processing: 2015-12-31.parquet
# Subset parquet saved to: {'C:\\Users\\32011\\Dropbox\\Rajib\\Call reports data\\Output\\rawdata\\Parq. folder\\2\\2015-12-31.parquet'}
# Shape: (6255, 9)
# Columns: ['IDRSSD', 'RCON1709', 'RCON1713', 'RCON1733', 'RCON1736', 'RCONG389', 'RCONG390', 'RCONG393', 'RCONG394']
# processing: 2016-03-31.parquet
# Subset parquet saved to: {'C:\\Users\\32011\\Dropbox\\Rajib\\Call reports data\\Output\\rawdata\\Parq. folder\\2\\2016-03-31.parquet'}
# Shape: (6181, 9)
# Columns: ['IDRSSD', 'RCON1709', 'RCON1713', 'RCON1733', 'RCON1736', 'RCONG389', 'RCONG390', 'RCONG393', 'RCONG394']
# processing: 2016-06-30.parquet
# Subset parquet saved to: {'C:\\Users\\32011\\Dropbox\\Rajib\\Call reports data\\Output\\rawdata\\Parq. folder\\2\\2016-06-30.parquet'}
# Shape: (6120, 9)
# Columns: ['IDRSSD', 'RCON1709', 'RCON1713', 'RCON1733', 'RCON1736', 'RCONG389', 'RCONG390', 'RCONG393', 'RCONG394']
# processing: 2016-09-30.parquet
# Subset parquet saved to: {'C:\\Users\\32011\\Dropbox\\Rajib\\Call reports data\\Output\\rawdata\\Parq. folder\\2\\2016-09-30.parquet'}
# Shape: (6040, 9)
# Columns: ['IDRSSD', 'RCON1709', 'RCON1713', 'RCON1733', 'RCON1736', 'RCONG389', 'RCONG390', 'RCONG393', 'RCONG394']
# processing: 2016-12-31.parquet
# Subset parquet saved to: {'C:\\Users\\32011\\Dropbox\\Rajib\\Call reports data\\Output\\rawdata\\Parq. folder\\2\\2016-12-31.parquet'}
# Shape: (5971, 9)
# Columns: ['IDRSSD', 'RCON1709', 'RCON1713', 'RCON1733', 'RCON1736', 'RCONG389', 'RCONG390', 'RCONG393', 'RCONG394']
# processing: 2017-03-31.parquet
# Subset parquet saved to: {'C:\\Users\\32011\\Dropbox\\Rajib\\Call reports data\\Output\\rawdata\\Parq. folder\\2\\2017-03-31.parquet'}
# Shape: (5912, 9)
# Columns: ['IDRSSD', 'RCON1709', 'RCON1713', 'RCON1733', 'RCON1736', 'RCONG389', 'RCONG390', 'RCONG393', 'RCONG394']
# processing: 2017-06-30.parquet
# Subset parquet saved to: {'C:\\Users\\32011\\Dropbox\\Rajib\\Call reports data\\Output\\rawdata\\Parq. folder\\2\\2017-06-30.parquet'}
# Shape: (5841, 9)
# Columns: ['IDRSSD', 'RCON1709', 'RCON1713', 'RCON1733', 'RCON1736', 'RCONG389', 'RCONG390', 'RCONG393', 'RCONG394']
# processing: 2017-09-30.parquet
# Subset parquet saved to: {'C:\\Users\\32011\\Dropbox\\Rajib\\Call reports data\\Output\\rawdata\\Parq. folder\\2\\2017-09-30.parquet'}
# Shape: (5794, 9)
# Columns: ['IDRSSD', 'RCON1709', 'RCON1713', 'RCON1733', 'RCON1736', 'RCONG389', 'RCONG390', 'RCONG393', 'RCONG394']
# processing: 2017-12-31.parquet
# Subset parquet saved to: {'C:\\Users\\32011\\Dropbox\\Rajib\\Call reports data\\Output\\rawdata\\Parq. folder\\2\\2017-12-31.parquet'}
# Shape: (5733, 9)
# Columns: ['IDRSSD', 'RCON1709', 'RCON1713', 'RCON1733', 'RCON1736', 'RCONG389', 'RCONG390', 'RCONG393', 'RCONG394']
# processing: 2018-03-31.parquet
# Subset parquet saved to: {'C:\\Users\\32011\\Dropbox\\Rajib\\Call reports data\\Output\\rawdata\\Parq. folder\\2\\2018-03-31.parquet'}
# Shape: (5663, 9)
# Columns: ['IDRSSD', 'RCON1709', 'RCON1713', 'RCON1733', 'RCON1736', 'RCONG389', 'RCONG390', 'RCONG393', 'RCONG394']
# processing: 2018-06-30.parquet
# Subset parquet saved to: {'C:\\Users\\32011\\Dropbox\\Rajib\\Call reports data\\Output\\rawdata\\Parq. folder\\2\\2018-06-30.parquet'}
# Shape: (5604, 9)
# Columns: ['IDRSSD', 'RCON1709', 'RCON1713', 'RCON1733', 'RCON1736', 'RCONG389', 'RCONG390', 'RCONG393', 'RCONG394']
# processing: 2018-09-30.parquet
# Subset parquet saved to: {'C:\\Users\\32011\\Dropbox\\Rajib\\Call reports data\\Output\\rawdata\\Parq. folder\\2\\2018-09-30.parquet'}
# Shape: (5533, 9)
# Columns: ['IDRSSD', 'RCON1709', 'RCON1713', 'RCON1733', 'RCON1736', 'RCONG389', 'RCONG390', 'RCONG393', 'RCONG394']
# processing: 2018-12-31.parquet
# Subset parquet saved to: {'C:\\Users\\32011\\Dropbox\\Rajib\\Call reports data\\Output\\rawdata\\Parq. folder\\2\\2018-12-31.parquet'}
# Shape: (5460, 9)
# Columns: ['IDRSSD', 'RCON1709', 'RCON1713', 'RCON1733', 'RCON1736', 'RCONG389', 'RCONG390', 'RCONG393', 'RCONG394']
# processing: 2019-03-31.parquet
# Subset parquet saved to: {'C:\\Users\\32011\\Dropbox\\Rajib\\Call reports data\\Output\\rawdata\\Parq. folder\\2\\2019-03-31.parquet'}
# Shape: (5414, 9)
# Columns: ['IDRSSD', 'RCON1709', 'RCON1713', 'RCON1733', 'RCON1736', 'RCONG389', 'RCONG390', 'RCONG393', 'RCONG394']
# processing: 2019-06-30.parquet
# Subset parquet saved to: {'C:\\Users\\32011\\Dropbox\\Rajib\\Call reports data\\Output\\rawdata\\Parq. folder\\2\\2019-06-30.parquet'}
# Shape: (5356, 9)
# Columns: ['IDRSSD', 'RCON1709', 'RCON1713', 'RCON1733', 'RCON1736', 'RCONG389', 'RCONG390', 'RCONG393', 'RCONG394']
# processing: 2019-09-30.parquet
# Subset parquet saved to: {'C:\\Users\\32011\\Dropbox\\Rajib\\Call reports data\\Output\\rawdata\\Parq. folder\\2\\2019-09-30.parquet'}
# Shape: (5310, 9)
# Columns: ['IDRSSD', 'RCON1709', 'RCON1713', 'RCON1733', 'RCON1736', 'RCONG389', 'RCONG390', 'RCONG393', 'RCONG394']
# processing: 2019-12-31.parquet
# Subset parquet saved to: {'C:\\Users\\32011\\Dropbox\\Rajib\\Call reports data\\Output\\rawdata\\Parq. folder\\2\\2019-12-31.parquet'}
# Shape: (5229, 9)
# Columns: ['IDRSSD', 'RCON1709', 'RCON1713', 'RCON1733', 'RCON1736', 'RCONG389', 'RCONG390', 'RCONG393', 'RCONG394']
# processing: 2020-03-31.parquet
# Subset parquet saved to: {'C:\\Users\\32011\\Dropbox\\Rajib\\Call reports data\\Output\\rawdata\\Parq. folder\\2\\2020-03-31.parquet'}
# Shape: (5167, 9)
# Columns: ['IDRSSD', 'RCON1709', 'RCON1713', 'RCON1733', 'RCON1736', 'RCONG389', 'RCONG390', 'RCONG393', 'RCONG394']
# processing: 2020-06-30.parquet
# Subset parquet saved to: {'C:\\Users\\32011\\Dropbox\\Rajib\\Call reports data\\Output\\rawdata\\Parq. folder\\2\\2020-06-30.parquet'}
# Shape: (5116, 9)
# Columns: ['IDRSSD', 'RCON1709', 'RCON1713', 'RCON1733', 'RCON1736', 'RCONG389', 'RCONG390', 'RCONG393', 'RCONG394']
# processing: 2020-09-30.parquet
# Subset parquet saved to: {'C:\\Users\\32011\\Dropbox\\Rajib\\Call reports data\\Output\\rawdata\\Parq. folder\\2\\2020-09-30.parquet'}
# Shape: (5085, 9)
# Columns: ['IDRSSD', 'RCON1709', 'RCON1713', 'RCON1733', 'RCON1736', 'RCONG389', 'RCONG390', 'RCONG393', 'RCONG394']
# processing: 2020-12-31.parquet
# Subset parquet saved to: {'C:\\Users\\32011\\Dropbox\\Rajib\\Call reports data\\Output\\rawdata\\Parq. folder\\2\\2020-12-31.parquet'}
# Shape: (5058, 9)
# Columns: ['IDRSSD', 'RCON1709', 'RCON1713', 'RCON1733', 'RCON1736', 'RCONG389', 'RCONG390', 'RCONG393', 'RCONG394']
# processing: 2021-03-31.parquet
# Subset parquet saved to: {'C:\\Users\\32011\\Dropbox\\Rajib\\Call reports data\\Output\\rawdata\\Parq. folder\\2\\2021-03-31.parquet'}
# Shape: (5041, 9)
# Columns: ['IDRSSD', 'RCON1709', 'RCON1713', 'RCON1733', 'RCON1736', 'RCONG389', 'RCONG390', 'RCONG393', 'RCONG394']
# processing: 2021-06-30.parquet
# Subset parquet saved to: {'C:\\Users\\32011\\Dropbox\\Rajib\\Call reports data\\Output\\rawdata\\Parq. folder\\2\\2021-06-30.parquet'}
# Shape: (5008, 9)
# Columns: ['IDRSSD', 'RCON1709', 'RCON1713', 'RCON1733', 'RCON1736', 'RCONG389', 'RCONG390', 'RCONG393', 'RCONG394']
# processing: 2021-09-30.parquet
# Subset parquet saved to: {'C:\\Users\\32011\\Dropbox\\Rajib\\Call reports data\\Output\\rawdata\\Parq. folder\\2\\2021-09-30.parquet'}
# Shape: (4970, 9)
# Columns: ['IDRSSD', 'RCON1709', 'RCON1713', 'RCON1733', 'RCON1736', 'RCONG389', 'RCONG390', 'RCONG393', 'RCONG394']
# processing: 2021-12-31.parquet
# Subset parquet saved to: {'C:\\Users\\32011\\Dropbox\\Rajib\\Call reports data\\Output\\rawdata\\Parq. folder\\2\\2021-12-31.parquet'}
# Shape: (4893, 9)
# Columns: ['IDRSSD', 'RCON1709', 'RCON1713', 'RCON1733', 'RCON1736', 'RCONG389', 'RCONG390', 'RCONG393', 'RCONG394']
# processing: 2022-03-31.parquet
# Subset parquet saved to: {'C:\\Users\\32011\\Dropbox\\Rajib\\Call reports data\\Output\\rawdata\\Parq. folder\\2\\2022-03-31.parquet'}
# Shape: (4858, 9)
# Columns: ['IDRSSD', 'RCON1709', 'RCON1713', 'RCON1733', 'RCON1736', 'RCONG389', 'RCONG390', 'RCONG393', 'RCONG394']
# processing: 2022-06-30.parquet
# Subset parquet saved to: {'C:\\Users\\32011\\Dropbox\\Rajib\\Call reports data\\Output\\rawdata\\Parq. folder\\2\\2022-06-30.parquet'}
# Shape: (4838, 9)
# Columns: ['IDRSSD', 'RCON1709', 'RCON1713', 'RCON1733', 'RCON1736', 'RCONG389', 'RCONG390', 'RCONG393', 'RCONG394']
# processing: 2022-09-30.parquet
# Subset parquet saved to: {'C:\\Users\\32011\\Dropbox\\Rajib\\Call reports data\\Output\\rawdata\\Parq. folder\\2\\2022-09-30.parquet'}
# Shape: (4808, 9)
# Columns: ['IDRSSD', 'RCON1709', 'RCON1713', 'RCON1733', 'RCON1736', 'RCONG389', 'RCONG390', 'RCONG393', 'RCONG394']
# processing: 2022-12-31.parquet
# Subset parquet saved to: {'C:\\Users\\32011\\Dropbox\\Rajib\\Call reports data\\Output\\rawdata\\Parq. folder\\2\\2022-12-31.parquet'}
# Shape: (4771, 9)
# Columns: ['IDRSSD', 'RCON1709', 'RCON1713', 'RCON1733', 'RCON1736', 'RCONG389', 'RCONG390', 'RCONG393', 'RCONG394']
# processing: 2023-03-31.parquet
# Subset parquet saved to: {'C:\\Users\\32011\\Dropbox\\Rajib\\Call reports data\\Output\\rawdata\\Parq. folder\\2\\2023-03-31.parquet'}
# Shape: (4739, 9)
# Columns: ['IDRSSD', 'RCON1709', 'RCON1713', 'RCON1733', 'RCON1736', 'RCONG389', 'RCONG390', 'RCONG393', 'RCONG394']
# processing: 2023-06-30.parquet
# Subset parquet saved to: {'C:\\Users\\32011\\Dropbox\\Rajib\\Call reports data\\Output\\rawdata\\Parq. folder\\2\\2023-06-30.parquet'}
# Shape: (4712, 9)
# Columns: ['IDRSSD', 'RCON1709', 'RCON1713', 'RCON1733', 'RCON1736', 'RCONG389', 'RCONG390', 'RCONG393', 'RCONG394']
# processing: 2023-09-30.parquet
# Subset parquet saved to: {'C:\\Users\\32011\\Dropbox\\Rajib\\Call reports data\\Output\\rawdata\\Parq. folder\\2\\2023-09-30.parquet'}
# Shape: (4682, 9)
# Columns: ['IDRSSD', 'RCON1709', 'RCON1713', 'RCON1733', 'RCON1736', 'RCONG389', 'RCONG390', 'RCONG393', 'RCONG394']
# processing: 2023-12-31.parquet
# Subset parquet saved to: {'C:\\Users\\32011\\Dropbox\\Rajib\\Call reports data\\Output\\rawdata\\Parq. folder\\2\\2023-12-31.parquet'}
# Shape: (4651, 9)
# Columns: ['IDRSSD', 'RCON1709', 'RCON1713', 'RCON1733', 'RCON1736', 'RCONG389', 'RCONG390', 'RCONG393', 'RCONG394']
# processing: 2024-03-31.parquet
# Subset parquet saved to: {'C:\\Users\\32011\\Dropbox\\Rajib\\Call reports data\\Output\\rawdata\\Parq. folder\\2\\2024-03-31.parquet'}
# Shape: (4634, 9)
# Columns: ['IDRSSD', 'RCON1709', 'RCON1713', 'RCON1733', 'RCON1736', 'RCONG389', 'RCONG390', 'RCONG393', 'RCONG394']
# processing: 2024-06-30.parquet
# Subset parquet saved to: {'C:\\Users\\32011\\Dropbox\\Rajib\\Call reports data\\Output\\rawdata\\Parq. folder\\2\\2024-06-30.parquet'}
# Shape: (4614, 9)
# Columns: ['IDRSSD', 'RCON1709', 'RCON1713', 'RCON1733', 'RCON1736', 'RCONG389', 'RCONG390', 'RCONG393', 'RCONG394']
# processing: 2024-09-30.parquet
# Subset parquet saved to: {'C:\\Users\\32011\\Dropbox\\Rajib\\Call reports data\\Output\\rawdata\\Parq. folder\\2\\2024-09-30.parquet'}
# Shape: (4585, 9)
# Columns: ['IDRSSD', 'RCON1709', 'RCON1713', 'RCON1733', 'RCON1736', 'RCONG389', 'RCONG390', 'RCONG393', 'RCONG394']
# processing: 2024-12-31.parquet
# Subset parquet saved to: {'C:\\Users\\32011\\Dropbox\\Rajib\\Call reports data\\Output\\rawdata\\Parq. folder\\2\\2024-12-31.parquet'}
# Shape: (4559, 9)
# Columns: ['IDRSSD', 'RCON1709', 'RCON1713', 'RCON1733', 'RCON1736', 'RCONG389', 'RCONG390', 'RCONG393', 'RCONG394']
# processing: 2025-03-31.parquet
# Subset parquet saved to: {'C:\\Users\\32011\\Dropbox\\Rajib\\Call reports data\\Output\\rawdata\\Parq. folder\\2\\2025-03-31.parquet'}
# Shape: (4527, 9)
# Columns: ['IDRSSD', 'RCON1709', 'RCON1713', 'RCON1733', 'RCON1736', 'RCONG389', 'RCONG390', 'RCONG393', 'RCONG394']
# processing: 2025-06-30.parquet
# Subset parquet saved to: {'C:\\Users\\32011\\Dropbox\\Rajib\\Call reports data\\Output\\rawdata\\Parq. folder\\2\\2025-06-30.parquet'}
# Shape: (4486, 9)
# Columns: ['IDRSSD', 'RCON1709', 'RCON1713', 'RCON1733', 'RCON1736', 'RCONG389', 'RCONG390', 'RCONG393', 'RCONG394']

# %% [markdown]
# Converting the parquet files to csv file

# %%
parquet_files_folder = r"C:\Users\32011\Dropbox\Rajib\Call reports data\Output\rawdata\Parq. folder\2" 
csv_output_folder = r"C:\Users\32011\Dropbox\Rajib\Call reports data\Output\rawdata\Excel folders"
os.makedirs(csv_output_folder, exist_ok = True)

for f in os.listdir(parquet_files_folder):
    if f.endswith(".parquet"):
        parquet_path = os.path.join(parquet_files_folder, f)
        csv_name = os.path.splitext(f)[0]+ ".csv"
        csv_path = os.path.join(csv_output_folder, csv_name)
        print(f"converting {f}")
        df = pd.read_parquet(parquet_path)
        df.to_csv(csv_path, index = False)

print(f"All files converted to excel")
# Out:
# converting 2001-03-31.parquet
# converting 2001-06-30.parquet
# converting 2001-09-30.parquet
# converting 2001-12-31.parquet
# converting 2002-03-31.parquet
# converting 2002-06-30.parquet
# converting 2002-09-30.parquet
# converting 2002-12-31.parquet
# converting 2003-03-31.parquet
# converting 2003-06-30.parquet
# converting 2003-09-30.parquet
# converting 2003-12-31.parquet
# converting 2004-03-31.parquet
# converting 2004-06-30.parquet
# converting 2004-09-30.parquet
# converting 2004-12-31.parquet
# converting 2005-03-31.parquet
# converting 2005-06-30.parquet
# converting 2005-09-30.parquet
# converting 2005-12-31.parquet
# converting 2006-03-31.parquet
# converting 2006-06-30.parquet
# converting 2006-09-30.parquet
# converting 2006-12-31.parquet
# converting 2007-03-31.parquet
# converting 2007-06-30.parquet
# converting 2007-09-30.parquet
# converting 2007-12-31.parquet
# converting 2008-03-31.parquet
# converting 2008-06-30.parquet
# converting 2008-09-30.parquet
# converting 2008-12-31.parquet
# converting 2009-03-31.parquet
# converting 2009-06-30.parquet
# converting 2009-09-30.parquet
# converting 2009-12-31.parquet
# converting 2010-03-31.parquet
# converting 2010-06-30.parquet
# converting 2010-09-30.parquet
# converting 2010-12-31.parquet
# converting 2011-03-31.parquet
# converting 2011-06-30.parquet
# converting 2011-09-30.parquet
# converting 2011-12-31.parquet
# converting 2012-03-31.parquet
# converting 2012-06-30.parquet
# converting 2012-09-30.parquet
# converting 2012-12-31.parquet
# converting 2013-03-31.parquet
# converting 2013-06-30.parquet
# converting 2013-09-30.parquet
# converting 2013-12-31.parquet
# converting 2014-03-31.parquet
# converting 2014-06-30.parquet
# converting 2014-09-30.parquet
# converting 2014-12-31.parquet
# converting 2015-03-31.parquet
# converting 2015-06-30.parquet
# converting 2015-09-30.parquet
# converting 2015-12-31.parquet
# converting 2016-03-31.parquet
# converting 2016-06-30.parquet
# converting 2016-09-30.parquet
# converting 2016-12-31.parquet
# converting 2017-03-31.parquet
# converting 2017-06-30.parquet
# converting 2017-09-30.parquet
# converting 2017-12-31.parquet
# converting 2018-03-31.parquet
# converting 2018-06-30.parquet
# converting 2018-09-30.parquet
# converting 2018-12-31.parquet
# converting 2019-03-31.parquet
# converting 2019-06-30.parquet
# converting 2019-09-30.parquet
# converting 2019-12-31.parquet
# converting 2020-03-31.parquet
# converting 2020-06-30.parquet
# converting 2020-09-30.parquet
# converting 2020-12-31.parquet
# converting 2021-03-31.parquet
# converting 2021-06-30.parquet
# converting 2021-09-30.parquet
# converting 2021-12-31.parquet
# converting 2022-03-31.parquet
# converting 2022-06-30.parquet
# converting 2022-09-30.parquet
# converting 2022-12-31.parquet
# converting 2023-03-31.parquet
# converting 2023-06-30.parquet
# converting 2023-09-30.parquet
# converting 2023-12-31.parquet
# converting 2024-03-31.parquet
# converting 2024-06-30.parquet
# converting 2024-09-30.parquet
# converting 2024-12-31.parquet
# converting 2025-03-31.parquet
# converting 2025-06-30.parquet
# converting subset_2001-03-31.parquet
# converting subset_2001-06-30.parquet
# converting subset_2001-09-30.parquet
# converting subset_2001-12-31.parquet
# converting subset_2002-03-31.parquet
# converting subset_2002-06-30.parquet
# converting subset_2002-09-30.parquet
# converting subset_2002-12-31.parquet
# converting subset_2003-03-31.parquet
# converting subset_2003-06-30.parquet
# converting subset_2003-09-30.parquet
# converting subset_2003-12-31.parquet
# converting subset_2004-03-31.parquet
# converting subset_2004-06-30.parquet
# converting subset_2004-09-30.parquet
# converting subset_2004-12-31.parquet
# converting subset_2005-03-31.parquet
# converting subset_2005-06-30.parquet
# converting subset_2005-09-30.parquet
# converting subset_2005-12-31.parquet
# converting subset_2006-03-31.parquet
# converting subset_2006-06-30.parquet
# converting subset_2006-09-30.parquet
# converting subset_2006-12-31.parquet
# converting subset_2007-03-31.parquet
# converting subset_2007-06-30.parquet
# converting subset_2007-09-30.parquet
# converting subset_2007-12-31.parquet
# converting subset_2008-03-31.parquet
# converting subset_2008-06-30.parquet
# converting subset_2008-09-30.parquet
# converting subset_2008-12-31.parquet
# converting subset_2009-03-31.parquet
# converting subset_2009-06-30.parquet
# converting subset_2009-09-30.parquet
# converting subset_2009-12-31.parquet
# converting subset_2010-03-31.parquet
# converting subset_2010-06-30.parquet
# converting subset_2010-09-30.parquet
# converting subset_2010-12-31.parquet
# converting subset_2011-03-31.parquet
# converting subset_2011-06-30.parquet
# converting subset_2011-09-30.parquet
# converting subset_2011-12-31.parquet
# converting subset_2012-03-31.parquet
# converting subset_2012-06-30.parquet
# converting subset_2012-09-30.parquet
# converting subset_2012-12-31.parquet
# converting subset_2013-03-31.parquet
# converting subset_2013-06-30.parquet
# converting subset_2013-09-30.parquet
# converting subset_2013-12-31.parquet
# converting subset_2014-03-31.parquet
# converting subset_2014-06-30.parquet
# converting subset_2014-09-30.parquet
# converting subset_2014-12-31.parquet
# converting subset_2015-03-31.parquet
# converting subset_2015-06-30.parquet
# converting subset_2015-09-30.parquet
# converting subset_2015-12-31.parquet
# converting subset_2016-03-31.parquet
# converting subset_2016-06-30.parquet
# converting subset_2016-09-30.parquet
# converting subset_2016-12-31.parquet
# converting subset_2017-03-31.parquet
# converting subset_2017-06-30.parquet
# converting subset_2017-09-30.parquet
# converting subset_2017-12-31.parquet
# converting subset_2018-03-31.parquet
# converting subset_2018-06-30.parquet
# converting subset_2018-09-30.parquet
# converting subset_2018-12-31.parquet
# converting subset_2019-03-31.parquet
# converting subset_2019-06-30.parquet
# converting subset_2019-09-30.parquet
# converting subset_2019-12-31.parquet
# converting subset_2020-03-31.parquet
# converting subset_2020-06-30.parquet
# converting subset_2020-09-30.parquet
# converting subset_2020-12-31.parquet
# converting subset_2021-03-31.parquet
# converting subset_2021-06-30.parquet
# converting subset_2021-09-30.parquet
# converting subset_2021-12-31.parquet
# converting subset_2022-03-31.parquet
# converting subset_2022-06-30.parquet
# converting subset_2022-09-30.parquet
# converting subset_2022-12-31.parquet
# converting subset_2023-03-31.parquet
# converting subset_2023-06-30.parquet
# converting subset_2023-09-30.parquet
# converting subset_2023-12-31.parquet
# converting subset_2024-03-31.parquet
# converting subset_2024-06-30.parquet
# converting subset_2024-09-30.parquet
# converting subset_2024-12-31.parquet
# converting subset_2025-03-31.parquet
# converting subset_2025-06-30.parquet
# All files converted to excel

# %%
csv_folder = r"C:\Users\32011\Dropbox\Call reports data\Output\Intermediate folders\csv_folder"
por_file = r"C:\Users\32011\Dropbox\Call reports data\Output\Final Output folder\Reporter_infor_file.xlsx"
op_folder = r"C:\Users\32011\Dropbox\Call reports data\Output\Final Output folder"
os.makedirs(op_folder, exist_ok = True)

dictionary_file = r"C:\Users\32011\Dropbox\Call reports data\Output\Final Output folder\Master_Dictionary_RC_RI_SU.xlsx"
codes_to_keep = ["Financial Institution Name"]

# Load POR file
por_df = pd.read_excel(por_file, dtype={"IDRSSD": "Int64"})
por_subset = por_df[["IDRSSD"] + [c for c in codes_to_keep if c in por_df.columns]]
dict_df = pd.read_excel(dictionary_file)
code_map = dict(zip(dict_df["Code"], dict_df["Description"]))
print("Files in csv_folder:", os.listdir(csv_folder))

for file in os.listdir(csv_folder):
    if file.endswith(".csv"): #and file not in [os.path.basename(por_file), os.path.basename(dictionary)]:
        csv_path = os.path.join(csv_folder, file)

        print(f"\n Processing {file} ...")

        # Load Excel file
        df = pd.read_csv(csv_path, dtype={"IDRSSD": "Int64"})

        # Merge with POR data (left join → keep all IDs from the Excel file)
        merged_df = pd.merge(df, por_subset, on="IDRSSD", how="left")

        renamed_cols = {col: code_map.get(col,col) for col in merged_df.columns}
        merged_df.rename(columns=renamed_cols, inplace=True)

        # Save back (overwrite or create new)
        output_path = os.path.join(op_folder, file)
        merged_df.to_csv(output_path, index=False)

        print(f"Updated file saved as {output_path}")
# Out:
# Files in csv_folder: ['subset_merged_2001-03-31.csv', 'subset_merged_2001-06-30.csv', 'subset_merged_2001-09-30.csv', 'subset_merged_2001-12-31.csv', 'subset_merged_2002-03-31.csv', 'subset_merged_2002-06-30.csv', 'subset_merged_2002-09-30.csv', 'subset_merged_2002-12-31.csv', 'subset_merged_2003-03-31.csv', 'subset_merged_2003-06-30.csv', 'subset_merged_2003-09-30.csv', 'subset_merged_2003-12-31.csv', 'subset_merged_2004-03-31.csv', 'subset_merged_2004-06-30.csv', 'subset_merged_2004-09-30.csv', 'subset_merged_2004-12-31.csv', 'subset_merged_2005-03-31.csv', 'subset_merged_2005-06-30.csv', 'subset_merged_2005-09-30.csv', 'subset_merged_2005-12-31.csv', 'subset_merged_2006-03-31.csv', 'subset_merged_2006-06-30.csv', 'subset_merged_2006-09-30.csv', 'subset_merged_2006-12-31.csv', 'subset_merged_2007-03-31.csv', 'subset_merged_2007-06-30.csv', 'subset_merged_2007-09-30.csv', 'subset_merged_2007-12-31.csv', 'subset_merged_2008-03-31.csv', 'subset_merged_2008-06-30.csv', 'subset_merged_2008-09-30.csv', 'subset_merged_2008-12-31.csv', 'subset_merged_2009-03-31.csv', 'subset_merged_2009-06-30.csv', 'subset_merged_2009-09-30.csv', 'subset_merged_2009-12-31.csv', 'subset_merged_2010-03-31.csv', 'subset_merged_2010-06-30.csv', 'subset_merged_2010-09-30.csv', 'subset_merged_2010-12-31.csv', 'subset_merged_2011-03-31.csv', 'subset_merged_2011-06-30.csv', 'subset_merged_2011-09-30.csv', 'subset_merged_2011-12-31.csv', 'subset_merged_2012-03-31.csv', 'subset_merged_2012-06-30.csv', 'subset_merged_2012-09-30.csv', 'subset_merged_2012-12-31.csv', 'subset_merged_2013-03-31.csv', 'subset_merged_2013-06-30.csv', 'subset_merged_2013-09-30.csv', 'subset_merged_2013-12-31.csv', 'subset_merged_2014-03-31.csv', 'subset_merged_2014-06-30.csv', 'subset_merged_2014-09-30.csv', 'subset_merged_2014-12-31.csv', 'subset_merged_2015-03-31.csv', 'subset_merged_2015-06-30.csv', 'subset_merged_2015-09-30.csv', 'subset_merged_2015-12-31.csv', 'subset_merged_2016-03-31.csv', 'subset_merged_2016-06-30.csv', 'subset_merged_2016-09-30.csv', 'subset_merged_2016-12-31.csv', 'subset_merged_2017-03-31.csv', 'subset_merged_2017-06-30.csv', 'subset_merged_2017-09-30.csv', 'subset_merged_2017-12-31.csv', 'subset_merged_2018-03-31.csv', 'subset_merged_2018-06-30.csv', 'subset_merged_2018-09-30.csv', 'subset_merged_2018-12-31.csv', 'subset_merged_2019-03-31.csv', 'subset_merged_2019-06-30.csv', 'subset_merged_2019-09-30.csv', 'subset_merged_2019-12-31.csv', 'subset_merged_2020-03-31.csv', 'subset_merged_2020-06-30.csv', 'subset_merged_2020-09-30.csv', 'subset_merged_2020-12-31.csv', 'subset_merged_2021-03-31.csv', 'subset_merged_2021-06-30.csv', 'subset_merged_2021-09-30.csv', 'subset_merged_2021-12-31.csv', 'subset_merged_2022-03-31.csv', 'subset_merged_2022-06-30.csv', 'subset_merged_2022-09-30.csv', 'subset_merged_2022-12-31.csv', 'subset_merged_2023-03-31.csv', 'subset_merged_2023-06-30.csv', 'subset_merged_2023-09-30.csv', 'subset_merged_2023-12-31.csv', 'subset_merged_2024-03-31.csv', 'subset_merged_2024-06-30.csv', 'subset_merged_2024-09-30.csv', 'subset_merged_2024-12-31.csv', 'subset_merged_2025-03-31.csv', 'subset_merged_2025-06-30.csv']
#
#  Processing subset_merged_2001-03-31.csv ...
# Updated file saved as C:\Users\32011\Dropbox\Call reports data\Output\Final Output folder\subset_merged_2001-03-31.csv
#
#  Processing subset_merged_2001-06-30.csv ...
# Updated file saved as C:\Users\32011\Dropbox\Call reports data\Output\Final Output folder\subset_merged_2001-06-30.csv
#
#  Processing subset_merged_2001-09-30.csv ...
# Updated file saved as C:\Users\32011\Dropbox\Call reports data\Output\Final Output folder\subset_merged_2001-09-30.csv
#
#  Processing subset_merged_2001-12-31.csv ...
# Updated file saved as C:\Users\32011\Dropbox\Call reports data\Output\Final Output folder\subset_merged_2001-12-31.csv
#
#  Processing subset_merged_2002-03-31.csv ...
# Updated file saved as C:\Users\32011\Dropbox\Call reports data\Output\Final Output folder\subset_merged_2002-03-31.csv
#
#  Processing subset_merged_2002-06-30.csv ...
# Updated file saved as C:\Users\32011\Dropbox\Call reports data\Output\Final Output folder\subset_merged_2002-06-30.csv
#
#  Processing subset_merged_2002-09-30.csv ...
# Updated file saved as C:\Users\32011\Dropbox\Call reports data\Output\Final Output folder\subset_merged_2002-09-30.csv
#
#  Processing subset_merged_2002-12-31.csv ...
# Updated file saved as C:\Users\32011\Dropbox\Call reports data\Output\Final Output folder\subset_merged_2002-12-31.csv
#
#  Processing subset_merged_2003-03-31.csv ...
# Updated file saved as C:\Users\32011\Dropbox\Call reports data\Output\Final Output folder\subset_merged_2003-03-31.csv
#
#  Processing subset_merged_2003-06-30.csv ...
# Updated file saved as C:\Users\32011\Dropbox\Call reports data\Output\Final Output folder\subset_merged_2003-06-30.csv
#
#  Processing subset_merged_2003-09-30.csv ...
# Updated file saved as C:\Users\32011\Dropbox\Call reports data\Output\Final Output folder\subset_merged_2003-09-30.csv
#
#  Processing subset_merged_2003-12-31.csv ...
# Updated file saved as C:\Users\32011\Dropbox\Call reports data\Output\Final Output folder\subset_merged_2003-12-31.csv
#
#  Processing subset_merged_2004-03-31.csv ...
# Updated file saved as C:\Users\32011\Dropbox\Call reports data\Output\Final Output folder\subset_merged_2004-03-31.csv
#
#  Processing subset_merged_2004-06-30.csv ...
# Updated file saved as C:\Users\32011\Dropbox\Call reports data\Output\Final Output folder\subset_merged_2004-06-30.csv
#
#  Processing subset_merged_2004-09-30.csv ...
# Updated file saved as C:\Users\32011\Dropbox\Call reports data\Output\Final Output folder\subset_merged_2004-09-30.csv
#
#  Processing subset_merged_2004-12-31.csv ...
# Updated file saved as C:\Users\32011\Dropbox\Call reports data\Output\Final Output folder\subset_merged_2004-12-31.csv
#
#  Processing subset_merged_2005-03-31.csv ...
# Updated file saved as C:\Users\32011\Dropbox\Call reports data\Output\Final Output folder\subset_merged_2005-03-31.csv
#
#  Processing subset_merged_2005-06-30.csv ...
# Updated file saved as C:\Users\32011\Dropbox\Call reports data\Output\Final Output folder\subset_merged_2005-06-30.csv
#
#  Processing subset_merged_2005-09-30.csv ...
# Updated file saved as C:\Users\32011\Dropbox\Call reports data\Output\Final Output folder\subset_merged_2005-09-30.csv
#
#  Processing subset_merged_2005-12-31.csv ...
# Updated file saved as C:\Users\32011\Dropbox\Call reports data\Output\Final Output folder\subset_merged_2005-12-31.csv
#
#  Processing subset_merged_2006-03-31.csv ...
# Updated file saved as C:\Users\32011\Dropbox\Call reports data\Output\Final Output folder\subset_merged_2006-03-31.csv
#
#  Processing subset_merged_2006-06-30.csv ...
# Updated file saved as C:\Users\32011\Dropbox\Call reports data\Output\Final Output folder\subset_merged_2006-06-30.csv
#
#  Processing subset_merged_2006-09-30.csv ...
# Updated file saved as C:\Users\32011\Dropbox\Call reports data\Output\Final Output folder\subset_merged_2006-09-30.csv
#
#  Processing subset_merged_2006-12-31.csv ...
# Updated file saved as C:\Users\32011\Dropbox\Call reports data\Output\Final Output folder\subset_merged_2006-12-31.csv
#
#  Processing subset_merged_2007-03-31.csv ...
# Updated file saved as C:\Users\32011\Dropbox\Call reports data\Output\Final Output folder\subset_merged_2007-03-31.csv
#
#  Processing subset_merged_2007-06-30.csv ...
# Updated file saved as C:\Users\32011\Dropbox\Call reports data\Output\Final Output folder\subset_merged_2007-06-30.csv
#
#  Processing subset_merged_2007-09-30.csv ...
# Updated file saved as C:\Users\32011\Dropbox\Call reports data\Output\Final Output folder\subset_merged_2007-09-30.csv
#
#  Processing subset_merged_2007-12-31.csv ...
# Updated file saved as C:\Users\32011\Dropbox\Call reports data\Output\Final Output folder\subset_merged_2007-12-31.csv
#
#  Processing subset_merged_2008-03-31.csv ...
# Updated file saved as C:\Users\32011\Dropbox\Call reports data\Output\Final Output folder\subset_merged_2008-03-31.csv
#
#  Processing subset_merged_2008-06-30.csv ...
# Updated file saved as C:\Users\32011\Dropbox\Call reports data\Output\Final Output folder\subset_merged_2008-06-30.csv
#
#  Processing subset_merged_2008-09-30.csv ...
# Updated file saved as C:\Users\32011\Dropbox\Call reports data\Output\Final Output folder\subset_merged_2008-09-30.csv
#
#  Processing subset_merged_2008-12-31.csv ...
# Updated file saved as C:\Users\32011\Dropbox\Call reports data\Output\Final Output folder\subset_merged_2008-12-31.csv
#
#  Processing subset_merged_2009-03-31.csv ...
# Updated file saved as C:\Users\32011\Dropbox\Call reports data\Output\Final Output folder\subset_merged_2009-03-31.csv
#
#  Processing subset_merged_2009-06-30.csv ...
# Updated file saved as C:\Users\32011\Dropbox\Call reports data\Output\Final Output folder\subset_merged_2009-06-30.csv
#
#  Processing subset_merged_2009-09-30.csv ...
# Updated file saved as C:\Users\32011\Dropbox\Call reports data\Output\Final Output folder\subset_merged_2009-09-30.csv
#
#  Processing subset_merged_2009-12-31.csv ...
# Updated file saved as C:\Users\32011\Dropbox\Call reports data\Output\Final Output folder\subset_merged_2009-12-31.csv
#
#  Processing subset_merged_2010-03-31.csv ...
# Updated file saved as C:\Users\32011\Dropbox\Call reports data\Output\Final Output folder\subset_merged_2010-03-31.csv
#
#  Processing subset_merged_2010-06-30.csv ...
# Updated file saved as C:\Users\32011\Dropbox\Call reports data\Output\Final Output folder\subset_merged_2010-06-30.csv
#
#  Processing subset_merged_2010-09-30.csv ...
# Updated file saved as C:\Users\32011\Dropbox\Call reports data\Output\Final Output folder\subset_merged_2010-09-30.csv
#
#  Processing subset_merged_2010-12-31.csv ...
# Updated file saved as C:\Users\32011\Dropbox\Call reports data\Output\Final Output folder\subset_merged_2010-12-31.csv
#
#  Processing subset_merged_2011-03-31.csv ...
# Updated file saved as C:\Users\32011\Dropbox\Call reports data\Output\Final Output folder\subset_merged_2011-03-31.csv
#
#  Processing subset_merged_2011-06-30.csv ...
# Updated file saved as C:\Users\32011\Dropbox\Call reports data\Output\Final Output folder\subset_merged_2011-06-30.csv
#
#  Processing subset_merged_2011-09-30.csv ...
# Updated file saved as C:\Users\32011\Dropbox\Call reports data\Output\Final Output folder\subset_merged_2011-09-30.csv
#
#  Processing subset_merged_2011-12-31.csv ...
# Updated file saved as C:\Users\32011\Dropbox\Call reports data\Output\Final Output folder\subset_merged_2011-12-31.csv
#
#  Processing subset_merged_2012-03-31.csv ...
# Updated file saved as C:\Users\32011\Dropbox\Call reports data\Output\Final Output folder\subset_merged_2012-03-31.csv
#
#  Processing subset_merged_2012-06-30.csv ...
# Updated file saved as C:\Users\32011\Dropbox\Call reports data\Output\Final Output folder\subset_merged_2012-06-30.csv
#
#  Processing subset_merged_2012-09-30.csv ...
# Updated file saved as C:\Users\32011\Dropbox\Call reports data\Output\Final Output folder\subset_merged_2012-09-30.csv
#
#  Processing subset_merged_2012-12-31.csv ...
# Updated file saved as C:\Users\32011\Dropbox\Call reports data\Output\Final Output folder\subset_merged_2012-12-31.csv
#
#  Processing subset_merged_2013-03-31.csv ...
# Updated file saved as C:\Users\32011\Dropbox\Call reports data\Output\Final Output folder\subset_merged_2013-03-31.csv
#
#  Processing subset_merged_2013-06-30.csv ...
# Updated file saved as C:\Users\32011\Dropbox\Call reports data\Output\Final Output folder\subset_merged_2013-06-30.csv
#
#  Processing subset_merged_2013-09-30.csv ...
# Updated file saved as C:\Users\32011\Dropbox\Call reports data\Output\Final Output folder\subset_merged_2013-09-30.csv
#
#  Processing subset_merged_2013-12-31.csv ...
# Updated file saved as C:\Users\32011\Dropbox\Call reports data\Output\Final Output folder\subset_merged_2013-12-31.csv
#
#  Processing subset_merged_2014-03-31.csv ...
# Updated file saved as C:\Users\32011\Dropbox\Call reports data\Output\Final Output folder\subset_merged_2014-03-31.csv
#
#  Processing subset_merged_2014-06-30.csv ...
# Updated file saved as C:\Users\32011\Dropbox\Call reports data\Output\Final Output folder\subset_merged_2014-06-30.csv
#
#  Processing subset_merged_2014-09-30.csv ...
# Updated file saved as C:\Users\32011\Dropbox\Call reports data\Output\Final Output folder\subset_merged_2014-09-30.csv
#
#  Processing subset_merged_2014-12-31.csv ...
# Updated file saved as C:\Users\32011\Dropbox\Call reports data\Output\Final Output folder\subset_merged_2014-12-31.csv
#
#  Processing subset_merged_2015-03-31.csv ...
# Updated file saved as C:\Users\32011\Dropbox\Call reports data\Output\Final Output folder\subset_merged_2015-03-31.csv
#
#  Processing subset_merged_2015-06-30.csv ...
# Updated file saved as C:\Users\32011\Dropbox\Call reports data\Output\Final Output folder\subset_merged_2015-06-30.csv
#
#  Processing subset_merged_2015-09-30.csv ...
# Updated file saved as C:\Users\32011\Dropbox\Call reports data\Output\Final Output folder\subset_merged_2015-09-30.csv
#
#  Processing subset_merged_2015-12-31.csv ...
# Updated file saved as C:\Users\32011\Dropbox\Call reports data\Output\Final Output folder\subset_merged_2015-12-31.csv
#
#  Processing subset_merged_2016-03-31.csv ...
# Updated file saved as C:\Users\32011\Dropbox\Call reports data\Output\Final Output folder\subset_merged_2016-03-31.csv
#
#  Processing subset_merged_2016-06-30.csv ...
# Updated file saved as C:\Users\32011\Dropbox\Call reports data\Output\Final Output folder\subset_merged_2016-06-30.csv
#
#  Processing subset_merged_2016-09-30.csv ...
# Updated file saved as C:\Users\32011\Dropbox\Call reports data\Output\Final Output folder\subset_merged_2016-09-30.csv
#
#  Processing subset_merged_2016-12-31.csv ...
# Updated file saved as C:\Users\32011\Dropbox\Call reports data\Output\Final Output folder\subset_merged_2016-12-31.csv
#
#  Processing subset_merged_2017-03-31.csv ...
# Updated file saved as C:\Users\32011\Dropbox\Call reports data\Output\Final Output folder\subset_merged_2017-03-31.csv
#
#  Processing subset_merged_2017-06-30.csv ...
# Updated file saved as C:\Users\32011\Dropbox\Call reports data\Output\Final Output folder\subset_merged_2017-06-30.csv
#
#  Processing subset_merged_2017-09-30.csv ...
# Updated file saved as C:\Users\32011\Dropbox\Call reports data\Output\Final Output folder\subset_merged_2017-09-30.csv
#
#  Processing subset_merged_2017-12-31.csv ...
# Updated file saved as C:\Users\32011\Dropbox\Call reports data\Output\Final Output folder\subset_merged_2017-12-31.csv
#
#  Processing subset_merged_2018-03-31.csv ...
# Updated file saved as C:\Users\32011\Dropbox\Call reports data\Output\Final Output folder\subset_merged_2018-03-31.csv
#
#  Processing subset_merged_2018-06-30.csv ...
# Updated file saved as C:\Users\32011\Dropbox\Call reports data\Output\Final Output folder\subset_merged_2018-06-30.csv
#
#  Processing subset_merged_2018-09-30.csv ...
# Updated file saved as C:\Users\32011\Dropbox\Call reports data\Output\Final Output folder\subset_merged_2018-09-30.csv
#
#  Processing subset_merged_2018-12-31.csv ...
# Updated file saved as C:\Users\32011\Dropbox\Call reports data\Output\Final Output folder\subset_merged_2018-12-31.csv
#
#  Processing subset_merged_2019-03-31.csv ...
# Updated file saved as C:\Users\32011\Dropbox\Call reports data\Output\Final Output folder\subset_merged_2019-03-31.csv
#
#  Processing subset_merged_2019-06-30.csv ...
# Updated file saved as C:\Users\32011\Dropbox\Call reports data\Output\Final Output folder\subset_merged_2019-06-30.csv
#
#  Processing subset_merged_2019-09-30.csv ...
# Updated file saved as C:\Users\32011\Dropbox\Call reports data\Output\Final Output folder\subset_merged_2019-09-30.csv
#
#  Processing subset_merged_2019-12-31.csv ...
# Updated file saved as C:\Users\32011\Dropbox\Call reports data\Output\Final Output folder\subset_merged_2019-12-31.csv
#
#  Processing subset_merged_2020-03-31.csv ...
# Updated file saved as C:\Users\32011\Dropbox\Call reports data\Output\Final Output folder\subset_merged_2020-03-31.csv
#
#  Processing subset_merged_2020-06-30.csv ...
# Updated file saved as C:\Users\32011\Dropbox\Call reports data\Output\Final Output folder\subset_merged_2020-06-30.csv
#
#  Processing subset_merged_2020-09-30.csv ...
# Updated file saved as C:\Users\32011\Dropbox\Call reports data\Output\Final Output folder\subset_merged_2020-09-30.csv
#
#  Processing subset_merged_2020-12-31.csv ...
# Updated file saved as C:\Users\32011\Dropbox\Call reports data\Output\Final Output folder\subset_merged_2020-12-31.csv
#
#  Processing subset_merged_2021-03-31.csv ...
# Updated file saved as C:\Users\32011\Dropbox\Call reports data\Output\Final Output folder\subset_merged_2021-03-31.csv
#
#  Processing subset_merged_2021-06-30.csv ...
# Updated file saved as C:\Users\32011\Dropbox\Call reports data\Output\Final Output folder\subset_merged_2021-06-30.csv
#
#  Processing subset_merged_2021-09-30.csv ...
# Updated file saved as C:\Users\32011\Dropbox\Call reports data\Output\Final Output folder\subset_merged_2021-09-30.csv
#
#  Processing subset_merged_2021-12-31.csv ...
# Updated file saved as C:\Users\32011\Dropbox\Call reports data\Output\Final Output folder\subset_merged_2021-12-31.csv
#
#  Processing subset_merged_2022-03-31.csv ...
# Updated file saved as C:\Users\32011\Dropbox\Call reports data\Output\Final Output folder\subset_merged_2022-03-31.csv
#
#  Processing subset_merged_2022-06-30.csv ...
# Updated file saved as C:\Users\32011\Dropbox\Call reports data\Output\Final Output folder\subset_merged_2022-06-30.csv
#
#  Processing subset_merged_2022-09-30.csv ...
# Updated file saved as C:\Users\32011\Dropbox\Call reports data\Output\Final Output folder\subset_merged_2022-09-30.csv
#
#  Processing subset_merged_2022-12-31.csv ...
# Updated file saved as C:\Users\32011\Dropbox\Call reports data\Output\Final Output folder\subset_merged_2022-12-31.csv
#
#  Processing subset_merged_2023-03-31.csv ...
# Updated file saved as C:\Users\32011\Dropbox\Call reports data\Output\Final Output folder\subset_merged_2023-03-31.csv
#
#  Processing subset_merged_2023-06-30.csv ...
# Updated file saved as C:\Users\32011\Dropbox\Call reports data\Output\Final Output folder\subset_merged_2023-06-30.csv
#
#  Processing subset_merged_2023-09-30.csv ...
# Updated file saved as C:\Users\32011\Dropbox\Call reports data\Output\Final Output folder\subset_merged_2023-09-30.csv
#
#  Processing subset_merged_2023-12-31.csv ...
# Updated file saved as C:\Users\32011\Dropbox\Call reports data\Output\Final Output folder\subset_merged_2023-12-31.csv
#
#  Processing subset_merged_2024-03-31.csv ...
# Updated file saved as C:\Users\32011\Dropbox\Call reports data\Output\Final Output folder\subset_merged_2024-03-31.csv
#
#  Processing subset_merged_2024-06-30.csv ...
# Updated file saved as C:\Users\32011\Dropbox\Call reports data\Output\Final Output folder\subset_merged_2024-06-30.csv
#
#  Processing subset_merged_2024-09-30.csv ...
# Updated file saved as C:\Users\32011\Dropbox\Call reports data\Output\Final Output folder\subset_merged_2024-09-30.csv
#
#  Processing subset_merged_2024-12-31.csv ...
# Updated file saved as C:\Users\32011\Dropbox\Call reports data\Output\Final Output folder\subset_merged_2024-12-31.csv
#
#  Processing subset_merged_2025-03-31.csv ...
# Updated file saved as C:\Users\32011\Dropbox\Call reports data\Output\Final Output folder\subset_merged_2025-03-31.csv
#
#  Processing subset_merged_2025-06-30.csv ...
# Updated file saved as C:\Users\32011\Dropbox\Call reports data\Output\Final Output folder\subset_merged_2025-06-30.csv

# %%
print("Files found:", os.listdir(por_file))
# Out:
# Files found: ['2020-03-31.xlsx', 'file.csv', 'Master_Dictionary_RC_RI_SU.xlsx', 'merged_parquet_all.csv', 'Reporter_infor_file.xlsx']
