# %%
import csv
import re
from pathlib import Path
from concurrent.futures import ThreadPoolExecutor, as_completed
import pandas as pd
import os
import sys
import time

ROOT_INPUT = Path(r"C:\Users\32011\Dropbox\Rajib\Call reports data\Raw Data\Input files")
OUT_DIR = Path(r"C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder")
ENCODING = "latin-1"
KEEP_SCHEDULE_PREFIXES = ("RC", "RI", "SU")  # prefixes we process
SAVE_FORMAT = "parquet"  # 'parquet' (fast) or 'xlsx' (readable, slower) or 'csv'
MAX_WORKERS = min(6, (os.cpu_count() or 2))  # threads for per-quarter parallel schedule processing

# %%
# compile regex once
SCHEDULE_RE = re.compile(r"Schedule\s+(.+?)\s+(\d{8})", flags=re.IGNORECASE)
PART_RE = re.compile(r"\((\d+)\s+of\s+(\d+)\)", flags=re.IGNORECASE)
NONWORD_RE = re.compile(r"[^\w\-_]")

def clean_token(s: str) -> str:
    if s is None:
        return ""
    s = s.strip()
    s = s.strip('"').strip("'")
    s = re.sub(r"\s+", " ", s)
    return s

def read_schedule_file_stream(path: Path):
    """
    Stream-read a tab-delimited schedule file robustly:
    - header = first row (csv.reader)
    - skip second row (descriptions)
    - stream rows: pad/truncate to header length
    - return (cols_list, rows_list)
    """
    cols = []
    rows = []
    with path.open("r", encoding=ENCODING, errors="replace", newline="") as fh:
        reader = csv.reader(fh, delimiter="\t")
        try:
            raw_cols = next(reader)
        except StopIteration:
            return [], []
        cols = [clean_token(c).upper() for c in raw_cols]
       # skip description row if present
        try:
            _ = next(reader)
        except StopIteration:
            return cols, []
        ncols = len(cols)
        for row in reader:
            # skip fully empty line
            if not any((cell and cell.strip()) for cell in row):
                continue
            # pad/truncate
            if len(row) < ncols:
                row = row + [""] * (ncols - len(row))
            elif len(row) > ncols:
                row = row[:ncols]
            rows.append(row)
    return cols, rows

def extract_code_and_date_from_stem(stem: str):
    """Extract schedule code and date (if present) from filename stem."""
    pm = PART_RE.search(stem)
    part = None
    if pm:
        part = (int(pm.group(1)), int(pm.group(2)))
    m = SCHEDULE_RE.search(stem)
    if m:
        code = m.group(1).strip()
        date = m.group(2)
    else:
        # fallback: look for 'Schedule ' followed by token
        m2 = re.search(r"Schedule\s+([A-Z0-9]+[A-Z0-9I]*)", stem, flags=re.IGNORECASE)
        if m2:
            code = m2.group(1).strip()
            date = None
        else:
            return None, None, part
    # clean code: remove spaces and stray chars
    code_clean = re.sub(r"[^\w]", "", code).upper()
    return code_clean, date, part

def normalize_out_name(stem: str):
    s = PART_RE.sub(lambda m: f"_{m.group(1)}_of_{m.group(2)}", stem)
    s = s.replace(" ", "_")
    s = NONWORD_RE.sub("", s)
    return s

def save_df(df: pd.DataFrame, out_file: Path, fmt: str):
    """Save DataFrame in requested format, with fallback to CSV if parquet unavailable."""
    out_file.parent.mkdir(parents=True, exist_ok=True)
    if fmt == "parquet":
        try:
            df.to_parquet(out_file, index=False)
            return
        except Exception as e:
            print(f"  ⚠ parquet write failed ({e}), falling back to csv: {out_file.with_suffix('.csv')}")
            df.to_csv(out_file.with_suffix('.csv'), index=False)
            return
    elif fmt == "xlsx":
        try:
            df.to_excel(out_file, index=False)
            return
        except Exception as e:
            print(f"  ⚠ xlsx write failed ({e}), falling back to csv: {out_file.with_suffix('.csv')}")
            df.to_csv(out_file.with_suffix('.csv'), index=False)
            return
    else:
        # csv
        df.to_csv(out_file.with_suffix('.csv'), index=False)
        return

def process_schedule_group(schedule_code, items, qout, qname, save_format):
    """
    items: list of tuples (Path, date, part)
    Returns list of saved file paths (for logging)
    """
    start_t = time.time()
    saved_files = []
    # sort items by part then filename
    items_sorted = sorted(items, key=lambda x: (x[2] is None, x[2] or 0, x[0].name))
    dfs = []
    headers = []
    filenames = []
    for fp, date, part in items_sorted:
        try:
            cols, rows = read_schedule_file_stream(fp)
        except Exception as e:
            print(f"    ⚠ Error reading {fp.name}: {e}")
            continue
        if not cols:
            print(f"    ⚠ No header found in {fp.name}, skipping")
            continue
        # quick check IDRSSD existence in header tokens
        if "IDRSSD" not in cols:
            print(f"    ⚠ Skipping {fp.name} — header lacks IDRSSD")
            continue
        # build DataFrame only once per file
        df = pd.DataFrame(rows, columns=cols)
        dfs.append(df)
        headers.append(tuple(df.columns.tolist()))
        filenames.append(fp.name)

    if not dfs:
        return saved_files
    # if multiple parts and headers identical -> vertical concat
    if len(dfs) > 1 and all(h == headers[0] for h in headers):
        merged_df = pd.concat(dfs, ignore_index=True)
        # keep as strings for speed; user can convert later selectively
        out_base = f"{schedule_code}_{qname}"
        out_name = normalize_out_name(out_base)
        if save_format == "parquet":
            out_file = qout / f"{out_name}.parquet"
        elif save_format == "xlsx":
            out_file = qout / f"{out_name}.xlsx"
        else:
            out_file = qout / f"{out_name}.csv"

        save_df(merged_df, out_file, save_format)
        saved_files.append(out_file)
        elapsed = time.time() - start_t
        print(f"  Merged {len(dfs)} parts -> {out_file}  rows={len(merged_df)} cols={len(merged_df.columns)}  ({elapsed:.1f}s)")
    else:
        # save parts individually (fast)
        for idx, (df, header, fname) in enumerate(zip(dfs, headers, filenames), start=1):
            part_match = PART_RE.search(fname)
            part_label = ""
            if part_match:
                part_label = f"_{part_match.group(1)}_of_{part_match.group(2)}"
            elif len(dfs) > 1:
                part_label = f"_part{idx}"

            out_base = f"{schedule_code}{part_label}_{qname}"
            out_name = normalize_out_name(out_base)
            if save_format == "parquet":
                out_file = qout / f"{out_name}.parquet"
            elif save_format == "xlsx":
                out_file = qout / f"{out_name}.xlsx"
            else:
                out_file = qout / f"{out_name}.csv"

            save_df(df, out_file, save_format)
            saved_files.append(out_file)
            print(f"    Saved part -> {out_file}  rows={len(df)} cols={len(df.columns)}")
    return saved_files

def process_quarter(qfolder: Path):
    qname = qfolder.name
    qout = OUT_DIR / qname
    qout.mkdir(parents=True, exist_ok=True)
    t0 = time.time()
    print(f"\nProcessing quarter: {qname}  (path: {qfolder})")
    txt_files = sorted(qfolder.glob("*.txt"))
    if not txt_files:
        print("  No txt files, skipping")
        return

    # group files by schedule code
    groups = {}
    for f in txt_files:
        stem = f.stem
        # skip POR and bulk
        if "POR" in stem.upper() or "BULK" in stem.upper():
            continue
        code, date, part = extract_code_and_date_from_stem(stem)
        if not code:
            continue
        if not any(code.startswith(pref) for pref in KEEP_SCHEDULE_PREFIXES):
            continue
        groups.setdefault(code, []).append((f, date, part))
    if not groups:
        print("  No RC/RI/SU schedules found in this quarter.")
        return

    # process groups in parallel threads for this quarter
    results = []
    with ThreadPoolExecutor(max_workers=max(1, MAX_WORKERS)) as ex:
        futures = {ex.submit(process_schedule_group, code, items, qout, qname, SAVE_FORMAT): code for code, items in groups.items()}
        for fut in as_completed(futures):
            code = futures[fut]
            try:
                saved = fut.result()
                results.extend(saved)
            except Exception as e:
                print(f"  ⚠ Error processing schedule {code}: {e}")

    elapsed = time.time() - t0
    print(f"Completed quarter {qname}: processed {len(groups)} schedules, saved {len(results)} files  ({elapsed:.1f}s)")

# -----------------------------------------------
# Run for all quarters (sequentially over quarters)
quarters = sorted([p for p in ROOT_INPUT.iterdir() if p.is_dir()])
if not quarters:
    print("No quarter folders found under:", ROOT_INPUT)
    sys.exit(0)

overall_start = time.time()
for q in quarters:
    process_quarter(q)

print("\nAll done. Total time:", time.time() - overall_start)
# Out:
# Processing quarter: 2001-03-31  (path: C:\Users\32011\Dropbox\Rajib\Call reports data\Raw Data\Input files\2001-03-31)
#     Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2001-03-31\RCCII_2001-03-31.parquet  rows=8857 cols=2
#     Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2001-03-31\RCA_2001-03-31.parquet  rows=8857 cols=19
#     Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2001-03-31\RCD_2001-03-31.parquet  rows=8857 cols=21
#     Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2001-03-31\RCEII_2001-03-31.parquet  rows=8857 cols=9
#     Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2001-03-31\RCB_2001-03-31.parquet  rows=8857 cols=196
#     Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2001-03-31\RCCI_2001-03-31.parquet  rows=8857 cols=80
#     Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2001-03-31\RC_2001-03-31.parquet  rows=8857 cols=78
#     Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2001-03-31\RCE_2001-03-31.parquet  rows=8857 cols=38
#     Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2001-03-31\RCI_2001-03-31.parquet  rows=8857 cols=4    Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2001-03-31\RCEI_2001-03-31.parquet  rows=8857 cols=38
#
#     Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2001-03-31\RCH_2001-03-31.parquet  rows=8857 cols=23
#     Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2001-03-31\RCG_2001-03-31.parquet  rows=8857 cols=30
#     Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2001-03-31\RCF_2001-03-31.parquet  rows=8857 cols=33
#     Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2001-03-31\RCK_2001-03-31.parquet  rows=8857 cols=34
#     Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2001-03-31\RCM_2001-03-31.parquet  rows=8857 cols=50
#     Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2001-03-31\RCN_2001-03-31.parquet  rows=8857 cols=129
#     Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2001-03-31\RCS_2001-03-31.parquet  rows=8857 cols=22
#     Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2001-03-31\RCO_2001-03-31.parquet  rows=8857 cols=37
#     Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2001-03-31\RIA_2001-03-31.parquet  rows=8857 cols=14
#     Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2001-03-31\RIBII_2001-03-31.parquet  rows=8857 cols=8
#     Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2001-03-31\RCL_2001-03-31.parquet  rows=8857 cols=171
#     Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2001-03-31\RID_2001-03-31.parquet  rows=8857 cols=14
#     Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2001-03-31\RIBI_2001-03-31.parquet  rows=8857 cols=50
#     Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2001-03-31\RI_2001-03-31.parquet  rows=8857 cols=72
#     Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2001-03-31\RIE_2001-03-31.parquet  rows=8857 cols=49
#     Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2001-03-31\RCR_1_of_2_2001-03-31.parquet  rows=8857 cols=242
#     Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2001-03-31\RCR_2_of_2_2001-03-31.parquet  rows=8857 cols=114
# Completed quarter 2001-03-31: processed 26 schedules, saved 27 files  (8.8s)
#
# Processing quarter: 2001-06-30  (path: C:\Users\32011\Dropbox\Rajib\Call reports data\Raw Data\Input files\2001-06-30)
#     Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2001-06-30\RCA_2001-06-30.parquet  rows=8790 cols=19
#     Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2001-06-30\RCD_2001-06-30.parquet  rows=8790 cols=21
#     Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2001-06-30\RCCII_2001-06-30.parquet  rows=8790 cols=32
#     Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2001-06-30\RCEII_2001-06-30.parquet  rows=8790 cols=9
#     Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2001-06-30\RCE_2001-06-30.parquet  rows=8790 cols=38
#     Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2001-06-30\RCEI_2001-06-30.parquet  rows=8790 cols=38
#     Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2001-06-30\RCB_2001-06-30.parquet  rows=8790 cols=196
#     Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2001-06-30\RCF_2001-06-30.parquet  rows=8790 cols=33
#     Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2001-06-30\RCI_2001-06-30.parquet  rows=8790 cols=4
#     Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2001-06-30\RC_2001-06-30.parquet  rows=8790 cols=78
#     Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2001-06-30\RCCI_2001-06-30.parquet  rows=8790 cols=80
#     Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2001-06-30\RCH_2001-06-30.parquet  rows=8790 cols=23
#     Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2001-06-30\RCG_2001-06-30.parquet  rows=8790 cols=30
#     Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2001-06-30\RCK_2001-06-30.parquet  rows=8790 cols=34
#     Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2001-06-30\RCO_2001-06-30.parquet  rows=8790 cols=37
#     Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2001-06-30\RCM_2001-06-30.parquet  rows=8790 cols=50
#     Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2001-06-30\RCN_2001-06-30.parquet  rows=8790 cols=129
#     Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2001-06-30\RIA_2001-06-30.parquet  rows=8790 cols=14
#     Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2001-06-30\RIBII_2001-06-30.parquet  rows=8790 cols=8
#     Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2001-06-30\RCL_2001-06-30.parquet  rows=8790 cols=171
#     Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2001-06-30\RI_2001-06-30.parquet  rows=8790 cols=72
#     Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2001-06-30\RID_2001-06-30.parquet  rows=8790 cols=14
#     Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2001-06-30\RIBI_2001-06-30.parquet  rows=8790 cols=50
#     Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2001-06-30\RCS_2001-06-30.parquet  rows=8790 cols=204
#     Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2001-06-30\RIE_2001-06-30.parquet  rows=8790 cols=47
#     Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2001-06-30\RCR_1_of_2_2001-06-30.parquet  rows=8790 cols=242
#     Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2001-06-30\RCR_2_of_2_2001-06-30.parquet  rows=8790 cols=114
# Completed quarter 2001-06-30: processed 26 schedules, saved 27 files  (10.0s)
#
# Processing quarter: 2001-09-30  (path: C:\Users\32011\Dropbox\Rajib\Call reports data\Raw Data\Input files\2001-09-30)
#     Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2001-09-30\RCA_2001-09-30.parquet  rows=8758 cols=19    Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2001-09-30\RCD_2001-09-30.parquet  rows=8758 cols=21
#
#     Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2001-09-30\RCCII_2001-09-30.parquet  rows=8758 cols=32
#     Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2001-09-30\RCEII_2001-09-30.parquet  rows=8758 cols=9
#     Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2001-09-30\RCCI_2001-09-30.parquet  rows=8758 cols=80
#     Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2001-09-30\RCB_2001-09-30.parquet  rows=8758 cols=196    Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2001-09-30\RCEI_2001-09-30.parquet  rows=8758 cols=38
#
#     Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2001-09-30\RCE_2001-09-30.parquet  rows=8758 cols=38
#     Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2001-09-30\RCF_2001-09-30.parquet  rows=8758 cols=33
#     Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2001-09-30\RC_2001-09-30.parquet  rows=8758 cols=78
#     Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2001-09-30\RCI_2001-09-30.parquet  rows=8758 cols=4
#     Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2001-09-30\RCG_2001-09-30.parquet  rows=8758 cols=30
#     Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2001-09-30\RCH_2001-09-30.parquet  rows=8758 cols=23
#     Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2001-09-30\RCM_2001-09-30.parquet  rows=8758 cols=50
#     Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2001-09-30\RCK_2001-09-30.parquet  rows=8758 cols=34
#     Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2001-09-30\RCO_2001-09-30.parquet  rows=8758 cols=37
#     Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2001-09-30\RCN_2001-09-30.parquet  rows=8758 cols=129
#     Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2001-09-30\RIA_2001-09-30.parquet  rows=8758 cols=14
#     Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2001-09-30\RCL_2001-09-30.parquet  rows=8758 cols=171
#     Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2001-09-30\RIBII_2001-09-30.parquet  rows=8758 cols=8
#     Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2001-09-30\RID_2001-09-30.parquet  rows=8758 cols=14
#     Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2001-09-30\RIBI_2001-09-30.parquet  rows=8758 cols=50
#     Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2001-09-30\RCS_2001-09-30.parquet  rows=8758 cols=204
#     Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2001-09-30\RI_2001-09-30.parquet  rows=8758 cols=72
#     Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2001-09-30\RIE_2001-09-30.parquet  rows=8758 cols=47
#     Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2001-09-30\RCR_1_of_2_2001-09-30.parquet  rows=8758 cols=242
#     Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2001-09-30\RCR_2_of_2_2001-09-30.parquet  rows=8758 cols=114
# Completed quarter 2001-09-30: processed 26 schedules, saved 27 files  (10.5s)
#
# Processing quarter: 2001-12-31  (path: C:\Users\32011\Dropbox\Rajib\Call reports data\Raw Data\Input files\2001-12-31)
#     Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2001-12-31\RCCII_2001-12-31.parquet  rows=8689 cols=32
#     Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2001-12-31\RCD_2001-12-31.parquet  rows=8689 cols=21
#     Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2001-12-31\RCA_2001-12-31.parquet  rows=8689 cols=19
#     Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2001-12-31\RCEII_2001-12-31.parquet  rows=8689 cols=9
#     Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2001-12-31\RCCI_2001-12-31.parquet  rows=8689 cols=80
#     Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2001-12-31\RCE_2001-12-31.parquet  rows=8689 cols=38
#     Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2001-12-31\RC_2001-12-31.parquet  rows=8689 cols=78
#     Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2001-12-31\RCEI_2001-12-31.parquet  rows=8689 cols=38
#     Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2001-12-31\RCI_2001-12-31.parquet  rows=8689 cols=4
#     Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2001-12-31\RCB_2001-12-31.parquet  rows=8689 cols=196
#     Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2001-12-31\RCF_2001-12-31.parquet  rows=8689 cols=33
#     Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2001-12-31\RCH_2001-12-31.parquet  rows=8689 cols=23
#     Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2001-12-31\RCG_2001-12-31.parquet  rows=8689 cols=30
#     Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2001-12-31\RCK_2001-12-31.parquet  rows=8689 cols=34
#     Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2001-12-31\RCO_2001-12-31.parquet  rows=8689 cols=37
#     Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2001-12-31\RCM_2001-12-31.parquet  rows=8689 cols=50
#     Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2001-12-31\RCN_2001-12-31.parquet  rows=8689 cols=129
#     Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2001-12-31\RCL_2001-12-31.parquet  rows=8689 cols=171
#     Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2001-12-31\RIA_2001-12-31.parquet  rows=8689 cols=14
#     Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2001-12-31\RIBII_2001-12-31.parquet  rows=8689 cols=8
#     Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2001-12-31\RCT_2001-12-31.parquet  rows=8689 cols=166
#     Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2001-12-31\RIBI_2001-12-31.parquet  rows=8689 cols=50
#     Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2001-12-31\RCS_2001-12-31.parquet  rows=8689 cols=204
#     Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2001-12-31\RID_2001-12-31.parquet  rows=8689 cols=14
#     Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2001-12-31\RI_2001-12-31.parquet  rows=8689 cols=72
#     Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2001-12-31\RIE_2001-12-31.parquet  rows=8689 cols=47
#     Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2001-12-31\RCR_1_of_2_2001-12-31.parquet  rows=8689 cols=242
#     Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2001-12-31\RCR_2_of_2_2001-12-31.parquet  rows=8689 cols=114
# Completed quarter 2001-12-31: processed 27 schedules, saved 28 files  (10.7s)
#
# Processing quarter: 2002-03-31  (path: C:\Users\32011\Dropbox\Rajib\Call reports data\Raw Data\Input files\2002-03-31)
#     Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2002-03-31\RCA_2002-03-31.parquet  rows=8605 cols=19
#     Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2002-03-31\RCD_2002-03-31.parquet  rows=8605 cols=21
#     Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2002-03-31\RCCII_2002-03-31.parquet  rows=8605 cols=32
#     Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2002-03-31\RCEII_2002-03-31.parquet  rows=8605 cols=9
#     Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2002-03-31\RCE_2002-03-31.parquet  rows=8605 cols=38
#     Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2002-03-31\RCEI_2002-03-31.parquet  rows=8605 cols=38
#     Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2002-03-31\RCB_2002-03-31.parquet  rows=8605 cols=196
#     Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2002-03-31\RCF_2002-03-31.parquet  rows=8605 cols=33
#     Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2002-03-31\RCCI_2002-03-31.parquet  rows=8605 cols=80
#     Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2002-03-31\RC_2002-03-31.parquet  rows=8605 cols=80
#     Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2002-03-31\RCI_2002-03-31.parquet  rows=8605 cols=4
#     Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2002-03-31\RCH_2002-03-31.parquet  rows=8605 cols=23
#     Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2002-03-31\RCG_2002-03-31.parquet  rows=8605 cols=30
#     Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2002-03-31\RCK_2002-03-31.parquet  rows=8605 cols=34
#     Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2002-03-31\RCM_2002-03-31.parquet  rows=8605 cols=50
#     Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2002-03-31\RCO_2002-03-31.parquet  rows=8605 cols=36
#     Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2002-03-31\RCN_2002-03-31.parquet  rows=8605 cols=138
#     Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2002-03-31\RCL_2002-03-31.parquet  rows=8605 cols=183
#     Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2002-03-31\RIA_2002-03-31.parquet  rows=8605 cols=14
#     Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2002-03-31\RCT_2002-03-31.parquet  rows=8605 cols=166
#     Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2002-03-31\RIBII_2002-03-31.parquet  rows=8605 cols=9
#     Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2002-03-31\RIBI_2002-03-31.parquet  rows=8605 cols=52
#     Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2002-03-31\RI_2002-03-31.parquet  rows=8605 cols=73
#     Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2002-03-31\RID_2002-03-31.parquet  rows=8605 cols=14
#     Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2002-03-31\RCS_2002-03-31.parquet  rows=8605 cols=204
#     Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2002-03-31\RIE_2002-03-31.parquet  rows=8605 cols=49
#     Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2002-03-31\RCR_1_of_2_2002-03-31.parquet  rows=8605 cols=242
#     Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2002-03-31\RCR_2_of_2_2002-03-31.parquet  rows=8605 cols=118
# Completed quarter 2002-03-31: processed 27 schedules, saved 28 files  (10.5s)
#
# Processing quarter: 2002-06-30  (path: C:\Users\32011\Dropbox\Rajib\Call reports data\Raw Data\Input files\2002-06-30)
#     Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2002-06-30\RCA_2002-06-30.parquet  rows=8562 cols=19    Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2002-06-30\RCD_2002-06-30.parquet  rows=8562 cols=21
#
#     Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2002-06-30\RCCII_2002-06-30.parquet  rows=8562 cols=32
#     Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2002-06-30\RCEII_2002-06-30.parquet  rows=8562 cols=9
#     Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2002-06-30\RCEI_2002-06-30.parquet  rows=8562 cols=38
#     Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2002-06-30\RCE_2002-06-30.parquet  rows=8562 cols=38
#     Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2002-06-30\RCF_2002-06-30.parquet  rows=8562 cols=33
#     Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2002-06-30\RCB_2002-06-30.parquet  rows=8562 cols=196
#     Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2002-06-30\RCCI_2002-06-30.parquet  rows=8562 cols=80
#     Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2002-06-30\RC_2002-06-30.parquet  rows=8562 cols=80
#     Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2002-06-30\RCI_2002-06-30.parquet  rows=8562 cols=4
#     Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2002-06-30\RCH_2002-06-30.parquet  rows=8562 cols=23
#     Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2002-06-30\RCG_2002-06-30.parquet  rows=8562 cols=30
#     Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2002-06-30\RCK_2002-06-30.parquet  rows=8562 cols=34    Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2002-06-30\RCM_2002-06-30.parquet  rows=8562 cols=50
#
#     Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2002-06-30\RCO_2002-06-30.parquet  rows=8562 cols=36
#     Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2002-06-30\RCN_2002-06-30.parquet  rows=8562 cols=138
#     Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2002-06-30\RCL_2002-06-30.parquet  rows=8562 cols=183
#     Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2002-06-30\RIA_2002-06-30.parquet  rows=8562 cols=14
#     Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2002-06-30\RI_2002-06-30.parquet  rows=8562 cols=73
#     Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2002-06-30\RCT_2002-06-30.parquet  rows=8562 cols=166
#     Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2002-06-30\RIBI_2002-06-30.parquet  rows=8562 cols=52
#     Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2002-06-30\RIBII_2002-06-30.parquet  rows=8562 cols=9
#     Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2002-06-30\RID_2002-06-30.parquet  rows=8562 cols=14
#     Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2002-06-30\RCS_2002-06-30.parquet  rows=8562 cols=204
#     Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2002-06-30\RIE_2002-06-30.parquet  rows=8562 cols=49
#     Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2002-06-30\RCR_1_of_2_2002-06-30.parquet  rows=8562 cols=242
#     Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2002-06-30\RCR_2_of_2_2002-06-30.parquet  rows=8562 cols=118
# Completed quarter 2002-06-30: processed 27 schedules, saved 28 files  (9.7s)
#
# Processing quarter: 2002-09-30  (path: C:\Users\32011\Dropbox\Rajib\Call reports data\Raw Data\Input files\2002-09-30)
#     Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2002-09-30\RCD_2002-09-30.parquet  rows=8522 cols=21    Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2002-09-30\RCA_2002-09-30.parquet  rows=8522 cols=19
#
#     Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2002-09-30\RCCII_2002-09-30.parquet  rows=8522 cols=32
#     Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2002-09-30\RCEII_2002-09-30.parquet  rows=8522 cols=9
#     Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2002-09-30\RCCI_2002-09-30.parquet  rows=8522 cols=80
#     Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2002-09-30\RC_2002-09-30.parquet  rows=8522 cols=80
#     Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2002-09-30\RCH_2002-09-30.parquet  rows=8522 cols=23
#     Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2002-09-30\RCEI_2002-09-30.parquet  rows=8522 cols=38
#     Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2002-09-30\RCE_2002-09-30.parquet  rows=8522 cols=38
#     Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2002-09-30\RCB_2002-09-30.parquet  rows=8522 cols=196
#     Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2002-09-30\RCI_2002-09-30.parquet  rows=8522 cols=4
#     Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2002-09-30\RCF_2002-09-30.parquet  rows=8522 cols=33
#     Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2002-09-30\RCG_2002-09-30.parquet  rows=8522 cols=30
#     Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2002-09-30\RCK_2002-09-30.parquet  rows=8522 cols=34
#     Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2002-09-30\RCO_2002-09-30.parquet  rows=8522 cols=36
#     Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2002-09-30\RCM_2002-09-30.parquet  rows=8522 cols=50
#     Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2002-09-30\RCN_2002-09-30.parquet  rows=8522 cols=138
#     Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2002-09-30\RCL_2002-09-30.parquet  rows=8522 cols=183
#     Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2002-09-30\RIA_2002-09-30.parquet  rows=8522 cols=14
#     Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2002-09-30\RIBII_2002-09-30.parquet  rows=8522 cols=9
#     Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2002-09-30\RCT_2002-09-30.parquet  rows=8522 cols=170
#     Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2002-09-30\RID_2002-09-30.parquet  rows=8522 cols=14
#     Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2002-09-30\RIBI_2002-09-30.parquet  rows=8522 cols=52
#     Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2002-09-30\RI_2002-09-30.parquet  rows=8522 cols=73
#     Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2002-09-30\RCS_2002-09-30.parquet  rows=8522 cols=204
#     Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2002-09-30\RIE_2002-09-30.parquet  rows=8522 cols=49
#     Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2002-09-30\RCR_1_of_2_2002-09-30.parquet  rows=8522 cols=242
#     Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2002-09-30\RCR_2_of_2_2002-09-30.parquet  rows=8522 cols=118
# Completed quarter 2002-09-30: processed 27 schedules, saved 28 files  (10.1s)
#
# Processing quarter: 2002-12-31  (path: C:\Users\32011\Dropbox\Rajib\Call reports data\Raw Data\Input files\2002-12-31)
#     Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2002-12-31\RCA_2002-12-31.parquet  rows=8468 cols=19    Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2002-12-31\RCD_2002-12-31.parquet  rows=8468 cols=21
#
#     Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2002-12-31\RCCII_2002-12-31.parquet  rows=8468 cols=32
#     Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2002-12-31\RCEII_2002-12-31.parquet  rows=8468 cols=9
#     Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2002-12-31\RCEI_2002-12-31.parquet  rows=8468 cols=38
#     Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2002-12-31\RCE_2002-12-31.parquet  rows=8468 cols=38
#     Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2002-12-31\RCF_2002-12-31.parquet  rows=8468 cols=33
#     Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2002-12-31\RC_2002-12-31.parquet  rows=8468 cols=80
#     Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2002-12-31\RCCI_2002-12-31.parquet  rows=8468 cols=80
#     Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2002-12-31\RCB_2002-12-31.parquet  rows=8468 cols=196
#     Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2002-12-31\RCI_2002-12-31.parquet  rows=8468 cols=4
#     Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2002-12-31\RCG_2002-12-31.parquet  rows=8468 cols=30
#     Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2002-12-31\RCH_2002-12-31.parquet  rows=8468 cols=23
#     Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2002-12-31\RCK_2002-12-31.parquet  rows=8468 cols=34
#     Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2002-12-31\RCM_2002-12-31.parquet  rows=8468 cols=50
#     Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2002-12-31\RCO_2002-12-31.parquet  rows=8468 cols=36
#     Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2002-12-31\RCN_2002-12-31.parquet  rows=8468 cols=138
#     Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2002-12-31\RCL_2002-12-31.parquet  rows=8468 cols=183
#     Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2002-12-31\RIA_2002-12-31.parquet  rows=8468 cols=14
#     Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2002-12-31\RI_2002-12-31.parquet  rows=8468 cols=73    Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2002-12-31\RIBII_2002-12-31.parquet  rows=8468 cols=9
#
#     Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2002-12-31\RCT_2002-12-31.parquet  rows=8468 cols=170
#     Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2002-12-31\RIBI_2002-12-31.parquet  rows=8468 cols=52
#     Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2002-12-31\RID_2002-12-31.parquet  rows=8468 cols=14
#     Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2002-12-31\RCS_2002-12-31.parquet  rows=8468 cols=204
#     Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2002-12-31\RIE_2002-12-31.parquet  rows=8468 cols=49
#     Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2002-12-31\RCR_1_of_2_2002-12-31.parquet  rows=8468 cols=242
#     Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2002-12-31\RCR_2_of_2_2002-12-31.parquet  rows=8468 cols=118
# Completed quarter 2002-12-31: processed 27 schedules, saved 28 files  (10.8s)
#
# Processing quarter: 2003-03-31  (path: C:\Users\32011\Dropbox\Rajib\Call reports data\Raw Data\Input files\2003-03-31)
#     Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2003-03-31\RCD_2003-03-31.parquet  rows=8445 cols=21    Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2003-03-31\RCA_2003-03-31.parquet  rows=8445 cols=19
#
#     Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2003-03-31\RCCII_2003-03-31.parquet  rows=8445 cols=32
#     Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2003-03-31\RCEII_2003-03-31.parquet  rows=8445 cols=9
#     Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2003-03-31\RCE_2003-03-31.parquet  rows=8445 cols=38
#     Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2003-03-31\RC_2003-03-31.parquet  rows=8445 cols=80
#     Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2003-03-31\RCF_2003-03-31.parquet  rows=8445 cols=35
#     Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2003-03-31\RCEI_2003-03-31.parquet  rows=8445 cols=38
#     Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2003-03-31\RCB_2003-03-31.parquet  rows=8445 cols=196
#     Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2003-03-31\RCCI_2003-03-31.parquet  rows=8445 cols=82
#     Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2003-03-31\RCI_2003-03-31.parquet  rows=8445 cols=4
#     Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2003-03-31\RCH_2003-03-31.parquet  rows=8445 cols=23
#     Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2003-03-31\RCG_2003-03-31.parquet  rows=8445 cols=30
#     Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2003-03-31\RCK_2003-03-31.parquet  rows=8445 cols=34
#     Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2003-03-31\RCO_2003-03-31.parquet  rows=8445 cols=36
#     Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2003-03-31\RCM_2003-03-31.parquet  rows=8445 cols=53
#     Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2003-03-31\RCN_2003-03-31.parquet  rows=8445 cols=138
#     Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2003-03-31\RCL_2003-03-31.parquet  rows=8445 cols=183    Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2003-03-31\RIA_2003-03-31.parquet  rows=8445 cols=14
#
#     Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2003-03-31\RIBII_2003-03-31.parquet  rows=8445 cols=12
#     Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2003-03-31\RID_2003-03-31.parquet  rows=8445 cols=14
#     Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2003-03-31\RCT_2003-03-31.parquet  rows=8445 cols=170
#     Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2003-03-31\RIBI_2003-03-31.parquet  rows=8445 cols=53    Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2003-03-31\RI_2003-03-31.parquet  rows=8445 cols=74
#
#     Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2003-03-31\RCS_2003-03-31.parquet  rows=8445 cols=220
#     Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2003-03-31\RIE_2003-03-31.parquet  rows=8445 cols=50
#     Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2003-03-31\RCR_1_of_2_2003-03-31.parquet  rows=8445 cols=242
#     Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2003-03-31\RCR_2_of_2_2003-03-31.parquet  rows=8445 cols=118
# Completed quarter 2003-03-31: processed 27 schedules, saved 28 files  (10.4s)
#
# Processing quarter: 2003-06-30  (path: C:\Users\32011\Dropbox\Rajib\Call reports data\Raw Data\Input files\2003-06-30)
#     Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2003-06-30\RCA_2003-06-30.parquet  rows=8410 cols=19
#     Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2003-06-30\RCD_2003-06-30.parquet  rows=8410 cols=21
#     Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2003-06-30\RCCII_2003-06-30.parquet  rows=8410 cols=32
#     Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2003-06-30\RCEII_2003-06-30.parquet  rows=8410 cols=9
#     Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2003-06-30\RCB_2003-06-30.parquet  rows=8410 cols=196
#     Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2003-06-30\RCEI_2003-06-30.parquet  rows=8410 cols=38
#     Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2003-06-30\RCE_2003-06-30.parquet  rows=8410 cols=38
#     Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2003-06-30\RCF_2003-06-30.parquet  rows=8410 cols=35
#     Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2003-06-30\RCCI_2003-06-30.parquet  rows=8410 cols=82
#     Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2003-06-30\RC_2003-06-30.parquet  rows=8410 cols=80
#     Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2003-06-30\RCI_2003-06-30.parquet  rows=8410 cols=4
#     Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2003-06-30\RCH_2003-06-30.parquet  rows=8410 cols=23
#     Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2003-06-30\RCG_2003-06-30.parquet  rows=8410 cols=30
#     Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2003-06-30\RCK_2003-06-30.parquet  rows=8410 cols=34
#     Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2003-06-30\RCM_2003-06-30.parquet  rows=8410 cols=53
#     Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2003-06-30\RCO_2003-06-30.parquet  rows=8410 cols=36
#     Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2003-06-30\RCN_2003-06-30.parquet  rows=8410 cols=138
#     Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2003-06-30\RIA_2003-06-30.parquet  rows=8410 cols=14
#     Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2003-06-30\RCL_2003-06-30.parquet  rows=8410 cols=183
#     Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2003-06-30\RI_2003-06-30.parquet  rows=8410 cols=75
#     Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2003-06-30\RIBII_2003-06-30.parquet  rows=8410 cols=12
#     Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2003-06-30\RCT_2003-06-30.parquet  rows=8410 cols=170
#     Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2003-06-30\RID_2003-06-30.parquet  rows=8410 cols=14
#     Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2003-06-30\RIBI_2003-06-30.parquet  rows=8410 cols=53
# ...
#     Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2024-12-31\RIE_2024-12-31.parquet  rows=4559 cols=55
#     Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2024-12-31\SU_2024-12-31.parquet  rows=4543 cols=29
#     Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2024-12-31\RCO_1_of_2_2024-12-31.parquet  rows=4543 cols=242
#     Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2024-12-31\RCRII_1_of_4_2024-12-31.parquet  rows=4543 cols=242
#     Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2024-12-31\RCO_2_of_2_2024-12-31.parquet  rows=4543 cols=173
#     Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2024-12-31\RCRII_2_of_4_2024-12-31.parquet  rows=4543 cols=242
#     Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2024-12-31\RCRII_3_of_4_2024-12-31.parquet  rows=4543 cols=242
#     Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2024-12-31\RCRII_4_of_4_2024-12-31.parquet  rows=4543 cols=24
# Completed quarter 2024-12-31: processed 33 schedules, saved 41 files  (12.3s)
#
# Processing quarter: 2025-03-31  (path: C:\Users\32011\Dropbox\Rajib\Call reports data\Raw Data\Input files\2025-03-31)
#     Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2025-03-31\RCA_2025-03-31.parquet  rows=4519 cols=13
#     Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2025-03-31\RCCII_2025-03-31.parquet  rows=4519 cols=32
#     Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2025-03-31\RCD_2025-03-31.parquet  rows=4519 cols=88
#     Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2025-03-31\RCEII_2025-03-31.parquet  rows=4519 cols=9
#     Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2025-03-31\RC_2025-03-31.parquet  rows=4519 cols=81
#     Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2025-03-31\RCE_2025-03-31.parquet  rows=4519 cols=53
#     Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2025-03-31\RCEI_2025-03-31.parquet  rows=4519 cols=57
#     Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2025-03-31\RCG_2025-03-31.parquet  rows=4519 cols=32
#     Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2025-03-31\RCCI_2025-03-31.parquet  rows=4519 cols=167
#     Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2025-03-31\RCF_2025-03-31.parquet  rows=4519 cols=41
#     Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2025-03-31\RCI_2025-03-31.parquet  rows=4519 cols=4
#     Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2025-03-31\RCH_2025-03-31.parquet  rows=4519 cols=35
#     Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2025-03-31\RCB_1_of_2_2025-03-31.parquet  rows=4519 cols=242
#     Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2025-03-31\RCB_2_of_2_2025-03-31.parquet  rows=4519 cols=62
#     Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2025-03-31\RCK_2025-03-31.parquet  rows=4519 cols=35
#     Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2025-03-31\RCM_2025-03-31.parquet  rows=4519 cols=96
#     Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2025-03-31\RCP_2025-03-31.parquet  rows=4519 cols=11
#     Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2025-03-31\RCN_2025-03-31.parquet  rows=4519 cols=239
#     Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2025-03-31\RCL_1_of_2_2025-03-31.parquet  rows=4519 cols=242
#     Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2025-03-31\RCL_2_of_2_2025-03-31.parquet  rows=4519 cols=59
#     Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2025-03-31\RCS_2025-03-31.parquet  rows=4519 cols=103
#     Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2025-03-31\RCRI_2025-03-31.parquet  rows=4519 cols=155
#     Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2025-03-31\RCQ_1_of_2_2025-03-31.parquet  rows=4519 cols=242
#     Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2025-03-31\RCQ_2_of_2_2025-03-31.parquet  rows=4519 cols=60
#     Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2025-03-31\RCV_2025-03-31.parquet  rows=4519 cols=42
#     Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2025-03-31\RIA_2025-03-31.parquet  rows=4519 cols=14
#     Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2025-03-31\RI_2025-03-31.parquet  rows=4519 cols=97
#     Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2025-03-31\RIBI_2025-03-31.parquet  rows=4519 cols=53
#     Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2025-03-31\RID_2025-03-31.parquet  rows=4519 cols=17    Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2025-03-31\RCT_1_of_2_2025-03-31.parquet  rows=4519 cols=242
#
#     Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2025-03-31\RIBII_2025-03-31.parquet  rows=4519 cols=31
#     Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2025-03-31\RIE_2025-03-31.parquet  rows=4527 cols=55
#     Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2025-03-31\RCT_2_of_2_2025-03-31.parquet  rows=4519 cols=29    Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2025-03-31\RIC_2025-03-31.parquet  rows=4519 cols=42
#
#     Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2025-03-31\RCRII_1_of_4_2025-03-31.parquet  rows=4519 cols=242
#     Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2025-03-31\SU_2025-03-31.parquet  rows=4519 cols=29
#     Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2025-03-31\RCRII_2_of_4_2025-03-31.parquet  rows=4519 cols=242
#     Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2025-03-31\RCO_1_of_2_2025-03-31.parquet  rows=4519 cols=242
#     Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2025-03-31\RCRII_3_of_4_2025-03-31.parquet  rows=4519 cols=242
#     Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2025-03-31\RCRII_4_of_4_2025-03-31.parquet  rows=4519 cols=24
#     Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2025-03-31\RCO_2_of_2_2025-03-31.parquet  rows=4519 cols=173
# Completed quarter 2025-03-31: processed 33 schedules, saved 41 files  (11.5s)
#
# Processing quarter: 2025-06-30  (path: C:\Users\32011\Dropbox\Rajib\Call reports data\Raw Data\Input files\2025-06-30)
#     Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2025-06-30\RCA_2025-06-30.parquet  rows=4477 cols=13
#     Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2025-06-30\RCD_2025-06-30.parquet  rows=4477 cols=88
#     Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2025-06-30\RCCII_2025-06-30.parquet  rows=4477 cols=32
#     Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2025-06-30\RCEII_2025-06-30.parquet  rows=4477 cols=9    Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2025-06-30\RC_2025-06-30.parquet  rows=4477 cols=81
#
#     Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2025-06-30\RCE_2025-06-30.parquet  rows=4477 cols=53
#     Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2025-06-30\RCEI_2025-06-30.parquet  rows=4477 cols=57
#     Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2025-06-30\RCCI_2025-06-30.parquet  rows=4477 cols=167
#     Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2025-06-30\RCI_2025-06-30.parquet  rows=4477 cols=4
#     Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2025-06-30\RCG_2025-06-30.parquet  rows=4477 cols=32
#     Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2025-06-30\RCH_2025-06-30.parquet  rows=4477 cols=35
#     Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2025-06-30\RCF_2025-06-30.parquet  rows=4477 cols=41
#     Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2025-06-30\RCB_1_of_2_2025-06-30.parquet  rows=4477 cols=242
#     Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2025-06-30\RCK_2025-06-30.parquet  rows=4477 cols=35
#     Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2025-06-30\RCB_2_of_2_2025-06-30.parquet  rows=4477 cols=62
#     Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2025-06-30\RCP_2025-06-30.parquet  rows=4477 cols=11
#     Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2025-06-30\RCM_2025-06-30.parquet  rows=4477 cols=96
#     Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2025-06-30\RCL_1_of_2_2025-06-30.parquet  rows=4477 cols=242
#     Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2025-06-30\RCL_2_of_2_2025-06-30.parquet  rows=4477 cols=59
#     Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2025-06-30\RCN_2025-06-30.parquet  rows=4477 cols=239
#     Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2025-06-30\RCQ_1_of_2_2025-06-30.parquet  rows=4477 cols=242
#     Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2025-06-30\RCRI_2025-06-30.parquet  rows=4477 cols=155
#     Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2025-06-30\RCS_2025-06-30.parquet  rows=4477 cols=103
#     Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2025-06-30\RCQ_2_of_2_2025-06-30.parquet  rows=4477 cols=60
#     Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2025-06-30\RCV_2025-06-30.parquet  rows=4477 cols=42
#     Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2025-06-30\RIA_2025-06-30.parquet  rows=4477 cols=14
#     Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2025-06-30\RI_2025-06-30.parquet  rows=4477 cols=97
#     Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2025-06-30\RCT_1_of_2_2025-06-30.parquet  rows=4477 cols=242
#     Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2025-06-30\RIBI_2025-06-30.parquet  rows=4477 cols=53
#     Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2025-06-30\RIBII_2025-06-30.parquet  rows=4477 cols=31
#     Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2025-06-30\RCT_2_of_2_2025-06-30.parquet  rows=4477 cols=29
#     Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2025-06-30\RID_2025-06-30.parquet  rows=4477 cols=17
#     Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2025-06-30\RIC_2025-06-30.parquet  rows=4477 cols=42
#     Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2025-06-30\SU_2025-06-30.parquet  rows=4477 cols=29    Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2025-06-30\RIE_2025-06-30.parquet  rows=4486 cols=55
#
#     Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2025-06-30\RCO_1_of_2_2025-06-30.parquet  rows=4477 cols=242
#     Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2025-06-30\RCRII_1_of_4_2025-06-30.parquet  rows=4477 cols=242
#     Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2025-06-30\RCO_2_of_2_2025-06-30.parquet  rows=4477 cols=173
#     Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2025-06-30\RCRII_2_of_4_2025-06-30.parquet  rows=4477 cols=242
#     Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2025-06-30\RCRII_3_of_4_2025-06-30.parquet  rows=4477 cols=242
#     Saved part -> C:\Users\32011\Dropbox\Rajib\Call reports data\Output\Intermediate folders\Parq. Quarters folder\2025-06-30\RCRII_4_of_4_2025-06-30.parquet  rows=4477 cols=24
# Completed quarter 2025-06-30: processed 33 schedules, saved 41 files  (11.4s)
#
# All done. Total time: 1944.071293592453
